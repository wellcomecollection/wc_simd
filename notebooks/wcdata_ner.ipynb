# %%
from wc_simd.utility import spark_path

# %%
from pyspark.sql import SparkSession


spark = SparkSession.builder \
    .appName("test_pyspark") \
    .config("spark.driver.memory", "12g") \
    .config("spark.executor.memory", "12g") \
    .config("spark.sql.orc.enableVectorizedReader", "false") \
    .config("spark.sql.parquet.columnarReaderBatchSize", "1024") \
    .config("spark.sql.orc.columnarReaderBatchSize", "1024") \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")
spark
# Out:
# 25/05/01 16:22:45 WARN Utils: Your hostname, Daniels-MacBook-Pro-1035.local resolves to a loopback address: 127.0.0.1; using 172.26.8.178 instead (on interface en0)
# 25/05/01 16:22:45 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/01 16:22:45 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/05/01 16:22:46 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://172.26.8.178:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>test_pyspark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType
import json
from pprint import pp

# %%
def print_json(id: str):
    row = spark.table("works").where(
        F.col("id") == id).first()
    row_dict = row.asDict(recursive=True)
    json_str = json.dumps(row_dict, indent=2)
    print(json_str)

# %% [markdown]
# # IIIF libraries
#
# - https://iiif-prezi.github.io/iiif-prezi3/
# - https://github.com/zimeon/iiif

# %% [markdown]
# # Collection Examples
#
# - Theme/Concept page: https://wellcomecollection.org/concepts/jabjbmgj

# %% [markdown]
# ## Work with many parts
# https://wellcomecollection.org/works/rqyum5sv

# %%
print_json("rqyum5sv")
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# {
#   "alternativeTitles": [],
#   "availabilities": [],
#   "contributors": [
#     {
#       "agent": {
#         "id": "wzggp2bj",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "label-derived",
#               "label": "Identifier derived from the label of the referent",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "twort, frederick william (1877-1950)"
#           }
#         ],
#         "label": "Twort, Frederick William (1877-1950)",
#         "type": "Agent"
#       },
#       "primary": true,
#       "roles": [],
#       "type": "Contributor"
#     }
#   ],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": "The material here consists largely of papers of Twort or about him, mainly his work at the Brown Institution. The bulk was arranged in files created by his son for the purpose of writing a biography. It includes: laboratory notes and correspondence, etc from the period 1903-1950,  including correspondence on the study of bacteriophages.",
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [],
#   "holdings": [],
#   "id": "rqyum5sv",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "calm-record-id",
#         "label": "Calm RecordIdentifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "e51fede1-e4ea-4ea4-89fc-e7301e24ad40"
#     },
#     {
#       "identifierType": {
#         "id": "calm-ref-no",
#         "label": "Calm RefNo",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "GC176"
#     },
#     {
#       "identifierType": {
#         "id": "calm-altref-no",
#         "label": "Calm AltRefNo",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "GC/176"
#     },
#     {
#       "identifierType": {
#         "id": "wellcome-accession-number",
#         "label": "Accession number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "854"
#     },
#     {
#       "identifierType": {
#         "id": "wellcome-accession-number",
#         "label": "Accession number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "1157"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b19689469"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "1968946"
#     }
#   ],
#   "images": [],
#   "items": [],
#   "languages": [],
#   "lettering": null,
#   "notes": [
#     {
#       "contents": [
#         "Twort went into research shortly after he qualified in medicine in 1900. In 1909 he was appointed Superintendent of the Brown Institution in South London, a post he held until the building was destroyed during the Blitz in 1944, apart from a period of service in Salonika at the Base Laboratories during World War I. In 1929 he was elected FRS and in 1931 the title of Professor of Bacteriology was conferred on him by the University of London. He did important work on the bacteriophage and was involved in controversy with F\u00e9lix d'H\u00e9relle over priority in research findings. Twort's research interests were wide and included developing improved wireless reception and work on removing impurities in latex. Described in an obituary as an 'erratic genius' he was no stranger to controversy, criticising his military superiors during his war service and initiating a legal case against the Medical Research Council when they terminated their funding to the Brown Institution.\nDetails of a biography of Twort by his son are given below."
#       ],
#       "noteType": {
#         "id": "biographical-note",
#         "label": "Biographical note",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "These papers were received in Oct 1993 from Dr Antony Twort, the son of FW Twort, and an additional accession in May 2003 from the same"
#       ],
#       "noteType": {
#         "id": "acquisition-note",
#         "label": "Acquisition note",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "At Wellcome Collection: PP/COL, PP/CRA, PP/GSW, PP/HAR, PP/VAN, SA/AMC, SA/HIS, SA/LIS, GC/4, 12, 33, 70, 130, 170, 177, 180, 200, 221, 278, RAMC, WA/BSR, WA/PHO."
#       ],
#       "noteType": {
#         "id": "related-material",
#         "label": "Related material",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "Most of the material was in post files, from which items have been removed and placed in acid free folders but otherwise kept together. Some slight rearrangement of the experimental notes in B.3 was undertaken to restore the sequence. The material relating to his wireless research, B.2, was loose in a file. One file of loose material labelled 'Various papers and letters', which includes career items, testimonials, congratulatory letters, and general correspondence with colleagues, associates and friends, has been sorted into several files now listed in Section A.\nThe sections are as follows:\nA\tPersonalia\nB\tResearch\nC\tCase against the Medical Research Council"
#       ],
#       "noteType": {
#         "id": "arrangement-note",
#         "label": "Arrangement",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     }
#   ],
#   "partOf": [],
#   "parts": [
#     {
#       "id": "hnmjdjrk",
#       "referenceNumber": "GC/176/A",
#       "title": "Personalia",
#       "totalDescendentParts": 9,
#       "totalParts": 7,
#       "type": "Section"
#     },
#     {
#       "id": "q86p94m9",
#       "referenceNumber": "GC/176/B",
#       "title": "Research",
#       "totalDescendentParts": 22,
#       "totalParts": 7,
#       "type": "Section"
#     },
#     {
#       "id": "dkhx5djp",
#       "referenceNumber": "GC/176/C",
#       "title": "Case against the Medical Research Council",
#       "totalDescendentParts": 7,
#       "totalParts": 2,
#       "type": "Section"
#     }
#   ],
#   "physicalDescription": "3 boxes",
#   "precededBy": [],
#   "production": [
#     {
#       "agents": [],
#       "dates": [
#         {
#           "label": "1896-1983",
#           "type": "Period"
#         }
#       ],
#       "function": null,
#       "label": "1896-1983",
#       "places": [],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": "GC/176",
#   "subjects": [
#     {
#       "concepts": [
#         {
#           "id": "tnjzjnct",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "bacteriology"
#             }
#           ],
#           "label": "Bacteriology",
#           "type": "Concept"
#         }
#       ],
#       "id": "tnjzjnct",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "label-derived",
#             "label": "Identifier derived from the label of the referent",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "bacteriology"
#         }
#       ],
#       "label": "Bacteriology",
#       "type": "Subject"
#     }
#   ],
#   "succeededBy": [],
#   "thumbnail": null,
#   "title": "Twort, Frederick William",
#   "type": "Collection",
#   "workType": {
#     "id": "h",
#     "label": "Archives and manuscripts",
#     "type": "Format"
#   }
# }

# %% [markdown]
# ## Work (Archives and manuscripts) (locationType.id: `iiif-presentation`)
# https://wellcomecollection.org/works/gumbfr2w

# %%
print_json("gumbfr2w")
# Out:
# [Stage 17:==============>                                           (1 + 3) / 4]
# {
#   "alternativeTitles": [],
#   "availabilities": [
#     {
#       "id": "closed-stores",
#       "label": "Closed stores",
#       "type": "Availability"
#     },
#     {
#       "id": "online",
#       "label": "Online",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": "Correspondence, diagrams, press-cuttings, patent applications.",
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [],
#   "holdings": [],
#   "id": "gumbfr2w",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "calm-record-id",
#         "label": "Calm RecordIdentifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "94ee05ca-b065-40f5-9e5e-78085048f0cb"
#     },
#     {
#       "identifierType": {
#         "id": "calm-ref-no",
#         "label": "Calm RefNo",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "GC176/B/2"
#     },
#     {
#       "identifierType": {
#         "id": "calm-altref-no",
#         "label": "Calm AltRefNo",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "GC/176/B/2"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b19131525"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "1913152"
#     },
#     {
#       "identifierType": {
#         "id": "wellcome-digcode",
#         "label": "Wellcome digcode",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "digadhoc"
#     },
#     {
#       "identifierType": {
#         "id": "mets",
#         "label": "METS",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b19131525"
#     }
#   ],
#   "images": [],
#   "items": [
#     {
#       "id": "cfsu233k",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "sierra-system-number",
#             "label": "Sierra system number",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "i17787580"
#         },
#         {
#           "identifierType": {
#             "id": "sierra-identifier",
#             "label": "Sierra identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "1778758"
#         }
#       ],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "online-request",
#                 "label": "Online request",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "open",
#                 "label": "Open",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": "Closed stores",
#           "license": null,
#           "linkText": null,
#           "locationType": {
#             "id": "closed-stores",
#             "label": "Closed stores",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "PhysicalLocation",
#           "url": null
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     },
#     {
#       "id": null,
#       "identifiers": [],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "view-online",
#                 "label": "View online",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "open-with-advisory",
#                 "label": "Open with advisory",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": null,
#           "license": {
#             "id": "inc",
#             "label": "In copyright",
#             "type": "License",
#             "url": "http://rightsstatements.org/vocab/InC/1.0/"
#           },
#           "linkText": null,
#           "locationType": {
#             "id": "iiif-presentation",
#             "label": "IIIF Presentation API",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "DigitalLocation",
#           "url": "https://iiif.wellcomecollection.org/presentation/v2/b19131525"
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     }
#   ],
#   "languages": [],
#   "lettering": null,
#   "notes": [],
#   "partOf": [
#     {
#       "id": "q86p94m9",
#       "partOf": [
#         {
#           "id": "rqyum5sv",
#           "partOf": null,
#           "referenceNumber": "GC/176",
#           "title": "Twort, Frederick William",
#           "totalDescendentParts": 41,
#           "totalParts": 3,
#           "type": "Collection"
#         }
#       ],
#       "referenceNumber": "GC/176/B",
#       "title": "Research",
#       "totalDescendentParts": 22,
#       "totalParts": 7,
#       "type": "Section"
#     }
#   ],
#   "parts": [],
#   "physicalDescription": "1 file",
#   "precededBy": [
#     {
#       "id": "x7t6cgnn",
#       "referenceNumber": "GC/176/B/1",
#       "title": "Bacteriophage",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     }
#   ],
#   "production": [
#     {
#       "agents": [],
#       "dates": [
#         {
#           "label": "1927-1933",
#           "type": "Period"
#         }
#       ],
#       "function": null,
#       "label": "1927-1933",
#       "places": [],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": "GC/176/B/2",
#   "subjects": [],
#   "succeededBy": [
#     {
#       "id": "mdbcb8ck",
#       "referenceNumber": "GC/176/B/3",
#       "title": "Laboratory notes",
#       "totalDescendentParts": 6,
#       "totalParts": 6,
#       "type": "Series"
#     },
#     {
#       "id": "cj4gxk8c",
#       "referenceNumber": "GC/176/B/4",
#       "title": "Shepherd's Industries: Rubber Research and 'DX'",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "akghfat3",
#       "referenceNumber": "GC/176/B/5",
#       "title": "Laboratory notebooks",
#       "totalDescendentParts": 9,
#       "totalParts": 9,
#       "type": "Series"
#     },
#     {
#       "id": "kdrdd85j",
#       "referenceNumber": "GC/176/B/6",
#       "title": "Loose notes 'The Essential Substance'",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "qfrzvnza",
#       "referenceNumber": "GC/176/B/7",
#       "title": "Ledger: 'The Brown Institution Special Research Account'",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     }
#   ],
#   "thumbnail": null,
#   "title": "Short-wave wireless coils",
#   "type": "Work",
#   "workType": {
#     "id": "h",
#     "label": "Archives and manuscripts",
#     "type": "Format"
#   }
# }
# 25/04/22 15:06:14 WARN HikariPool: HikariPool-1 - Thread starvation or clock leap detected (housekeeper delta=14m57s49ms).
# 25/04/22 15:06:14 WARN HikariPool: HikariPool-2 - Thread starvation or clock leap detected (housekeeper delta=14m57s48ms).

# %% [markdown]
# ## Work (Digital Images) with one image (locationType.id: `iiif-image`)
# - https://wellcomecollection.org/works/nf7cjmsg
# - Image: https://iiif.wellcomecollection.org/image/N0014023/full/600,/0/default.jpg (Change "600" for different width)

# %%
print_json("nf7cjmsg")
# Out:
# [Stage 19:==============>                                           (1 + 3) / 4]
# {
#   "alternativeTitles": [],
#   "availabilities": [
#     {
#       "id": "online",
#       "label": "Online",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": "Scan - axial, brain",
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [],
#   "holdings": [],
#   "id": "nf7cjmsg",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "miro-image-number",
#         "label": "Miro image number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "N0014023"
#     },
#     {
#       "identifierType": {
#         "id": "miro-library-reference",
#         "label": "Miro library reference",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "NMSB Frame No NOVIDEO"
#     }
#   ],
#   "images": [
#     {
#       "id": "msg3gj54",
#       "type": "Image"
#     }
#   ],
#   "items": [
#     {
#       "id": null,
#       "identifiers": [],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "view-online",
#                 "label": "View online",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "open",
#                 "label": "Open",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": "Wellcome Collection",
#           "label": null,
#           "license": {
#             "id": "cc-by",
#             "label": "Attribution 4.0 International (CC BY 4.0)",
#             "type": "License",
#             "url": "http://creativecommons.org/licenses/by/4.0/"
#           },
#           "linkText": null,
#           "locationType": {
#             "id": "iiif-image",
#             "label": "IIIF Image API",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "DigitalLocation",
#           "url": "https://iiif.wellcomecollection.org/image/N0014023/info.json"
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     }
#   ],
#   "languages": [],
#   "lettering": null,
#   "notes": [],
#   "partOf": [],
#   "parts": [],
#   "physicalDescription": null,
#   "precededBy": [],
#   "production": [],
#   "referenceNumber": null,
#   "subjects": [],
#   "succeededBy": [],
#   "thumbnail": {
#     "accessConditions": [],
#     "license": {
#       "id": "cc-by",
#       "label": "Attribution 4.0 International (CC BY 4.0)",
#       "type": "License",
#       "url": "http://creativecommons.org/licenses/by/4.0/"
#     },
#     "locationType": {
#       "id": "thumbnail-image",
#       "label": "Thumbnail image",
#       "type": "LocationType"
#     },
#     "type": "DigitalLocation",
#     "url": "https://iiif.wellcomecollection.org/image/N0014023/full/300,/0/default.jpg"
#   },
#   "title": "Hypertensive, vascular disease",
#   "type": "Work",
#   "workType": {
#     "id": "q",
#     "label": "Digital Images",
#     "type": "Format"
#   }
# }

# %% [markdown]
# ## Work (Book) (No digital) (locationType.id: `open-shelves`)
# - https://wellcomecollection.org/works/m6uy6knc

# %%
print_json("m6uy6knc")
# Out:
# [Stage 6:==============>                                            (1 + 3) / 4]
# {
#   "alternativeTitles": [],
#   "availabilities": [
#     {
#       "id": "open-shelves",
#       "label": "Open shelves",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [
#     {
#       "agent": {
#         "id": "rcncxsjb",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "lc-names",
#               "label": "Library of Congress Name authority records",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "n80117079"
#           }
#         ],
#         "label": "Simoons, Frederick J.",
#         "type": "Person"
#       },
#       "primary": true,
#       "roles": [],
#       "type": "Contributor"
#     }
#   ],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": null,
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [],
#   "holdings": [],
#   "id": "m6uy6knc",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b10274911"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "1027491"
#     },
#     {
#       "identifierType": {
#         "id": "isbn",
#         "label": "International Standard Book Number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "0299159000"
#     },
#     {
#       "identifierType": {
#         "id": "isbn",
#         "label": "International Standard Book Number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "0299159043"
#     }
#   ],
#   "images": [],
#   "items": [
#     {
#       "id": "vfsrwfby",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "sierra-system-number",
#             "label": "Sierra system number",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "i10320039"
#         },
#         {
#           "identifierType": {
#             "id": "sierra-identifier",
#             "label": "Sierra identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "1032003"
#         }
#       ],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "open-shelves",
#                 "label": "Open shelves",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": null,
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": "History of Medicine",
#           "license": null,
#           "linkText": null,
#           "locationType": {
#             "id": "open-shelves",
#             "label": "Open shelves",
#             "type": "LocationType"
#           },
#           "shelfmark": "AQ.U",
#           "type": "PhysicalLocation",
#           "url": null
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     }
#   ],
#   "languages": [
#     {
#       "id": "eng",
#       "label": "English",
#       "type": "Language"
#     }
#   ],
#   "lettering": null,
#   "notes": [
#     {
#       "contents": [
#         "Includes bibliographic references and index"
#       ],
#       "noteType": {
#         "id": "bibliographic-info",
#         "label": "Bibliographic information",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "Copy 1 Supplier/Donor: CMB"
#       ],
#       "noteType": {
#         "id": "general-note",
#         "label": "Notes",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     }
#   ],
#   "partOf": [],
#   "parts": [],
#   "physicalDescription": "xv, 568 pages : illustrations, map ; 24 cm",
#   "precededBy": [],
#   "production": [
#     {
#       "agents": [
#         {
#           "label": "University of Wisconsin Press",
#           "type": "Agent"
#         }
#       ],
#       "dates": [
#         {
#           "label": "[1998], \u00a91998",
#           "type": "Period"
#         }
#       ],
#       "function": null,
#       "label": "Madison : University of Wisconsin Press, [1998], \u00a91998.",
#       "places": [
#         {
#           "label": "Madison",
#           "type": "Place"
#         }
#       ],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": null,
#   "subjects": [
#     {
#       "concepts": [
#         {
#           "id": "usqt7qt8",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "plants"
#             }
#           ],
#           "label": "Plants",
#           "type": "Concept"
#         },
#         {
#           "id": "m7x7qxg6",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "history"
#             }
#           ],
#           "label": "history",
#           "type": "Concept"
#         }
#       ],
#       "id": "esgbhpdu",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D010944"
#         }
#       ],
#       "label": "Plants - history",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "c8w3e37q",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D008273"
#             }
#           ],
#           "label": "Magic",
#           "type": "Concept"
#         }
#       ],
#       "id": "c8w3e37q",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D008273"
#         }
#       ],
#       "label": "Magic",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "jszzsnpj",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D005495"
#             }
#           ],
#           "label": "Folklore",
#           "type": "Concept"
#         }
#       ],
#       "id": "jszzsnpj",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D005495"
#         }
#       ],
#       "label": "Folklore",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "akpq4prm",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D011035"
#             }
#           ],
#           "label": "Podophyllum",
#           "type": "Concept"
#         }
#       ],
#       "id": "akpq4prm",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D011035"
#         }
#       ],
#       "label": "Podophyllum",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "bj8j5d6t",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D018649"
#             }
#           ],
#           "label": "Ocimum basilicum",
#           "type": "Concept"
#         }
#       ],
#       "id": "bj8j5d6t",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D018649"
#         }
#       ],
#       "label": "Ocimum basilicum",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "jabjbmgj",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D005737"
#             }
#           ],
#           "label": "Garlic",
#           "type": "Concept"
#         }
#       ],
#       "id": "jabjbmgj",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D005737"
#         }
#       ],
#       "label": "Garlic",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "phrahkz4",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D005894"
#             }
#           ],
#           "label": "Panax",
#           "type": "Concept"
#         }
#       ],
#       "id": "phrahkz4",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D005894"
#         }
#       ],
#       "label": "Panax",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "yjdwjxk2",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D007887"
#             }
#           ],
#           "label": "Fabaceae",
#           "type": "Concept"
#         }
#       ],
#       "id": "yjdwjxk2",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D007887"
#         }
#       ],
#       "label": "Fabaceae",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "c3vm7m37",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "plants, medicinal"
#             }
#           ],
#           "label": "Plants, Medicinal",
#           "type": "Concept"
#         },
#         {
#           "id": "m7x7qxg6",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "history"
#             }
#           ],
#           "label": "history",
#           "type": "Concept"
#         }
#       ],
#       "id": "j3kse2wd",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D010946"
#         }
#       ],
#       "label": "Plants, Medicinal - history",
#       "type": "Subject"
#     }
#   ],
#   "succeededBy": [],
#   "thumbnail": null,
#   "title": "Plants of life, plants of death / Frederick J. Simoons.",
#   "type": "Work",
#   "workType": {
#     "id": "a",
#     "label": "Books",
#     "type": "Format"
#   }
# }

# %% [markdown]
# ## Work (Book) (locationType.id: `online-resource`) (go.gale.com)
# - https://wellcomecollection.org/works/mtbrsqa8
# - https://go.gale.com/ps/i.do?p=ECCO&u=wellcome&id=GALE%7CCW0123958160&v=2.1&it=r

# %%
print_json("mtbrsqa8")
# Out:
# {
#   "alternativeTitles": [
#     "Case of His Majesties sugar plantations (Online)"
#   ],
#   "availabilities": [
#     {
#       "id": "online",
#       "label": "Online",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": null,
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [],
#   "holdings": [
#     {
#       "enumeration": [
#         "Full text available: 1670."
#       ],
#       "location": {
#         "accessConditions": [
#           {
#             "method": {
#               "id": "view-online",
#               "label": "View online",
#               "type": "AccessMethod"
#             },
#             "status": {
#               "id": "licensed-resources",
#               "label": "Licensed resources",
#               "type": "AccessStatus"
#             },
#             "type": "AccessCondition"
#           }
#         ],
#         "label": null,
#         "linkText": "Available in Eighteenth Century Collections Online.",
#         "locationType": {
#           "id": "online-resource",
#           "label": "Online resource",
#           "type": "LocationType"
#         },
#         "shelfmark": null,
#         "type": "DigitalLocation",
#         "url": "https://resolver.ebscohost.com/Redirect/PRL?EPPackageLocationID=4205.1530096.0&epcustomerid=s7451719"
#       },
#       "note": null,
#       "type": "Holdings"
#     }
#   ],
#   "id": "mtbrsqa8",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "ebsco-alt-lookup",
#         "label": "EBSCO lookup identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "ebs1530096e"
#     }
#   ],
#   "images": [],
#   "items": [],
#   "languages": [],
#   "lettering": null,
#   "notes": [],
#   "partOf": [
#     {
#       "id": null,
#       "partOf": null,
#       "referenceNumber": null,
#       "title": "Eighteenth Century Collections Online",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Series"
#     }
#   ],
#   "parts": [],
#   "physicalDescription": null,
#   "precededBy": [],
#   "production": [
#     {
#       "agents": [
#         {
#           "label": "ProQuest UMI Dissertation Publishing",
#           "type": "Agent"
#         }
#       ],
#       "dates": [
#         {
#           "label": "[1670]",
#           "type": "Period"
#         }
#       ],
#       "function": null,
#       "label": "ProQuest UMI Dissertation Publishing [1670]",
#       "places": [],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": null,
#   "subjects": [],
#   "succeededBy": [],
#   "thumbnail": null,
#   "title": "The case of His Majesties sugar plantations",
#   "type": "Work",
#   "workType": {
#     "id": "v",
#     "label": "E-books",
#     "type": "Format"
#   }
# }

# %% [markdown]
# ## Work (Book) (locationType.id: `online-resource`) (www.proquest.com/eebo)
# - https://wellcomecollection.org/works/u7xtg8mj

# %%
print_json("u7xtg8mj")
# Out:
# [Stage 12:======================================>                  (8 + 4) / 12]
# {
#   "alternativeTitles": [],
#   "availabilities": [
#     {
#       "id": "online",
#       "label": "Online",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [
#     {
#       "agent": {
#         "id": "ckk9ffrq",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "lc-names",
#               "label": "Library of Congress Name authority records",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "n84177453"
#           }
#         ],
#         "label": "Coley, Henry, 1633-1704?",
#         "type": "Person"
#       },
#       "primary": true,
#       "roles": [],
#       "type": "Contributor"
#     }
#   ],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": null,
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [
#     {
#       "concepts": [
#         {
#           "id": "kqkakf66",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "electronic books"
#             }
#           ],
#           "label": "Electronic books",
#           "type": "Genre"
#         }
#       ],
#       "label": "Electronic books",
#       "type": "Genre"
#     }
#   ],
#   "holdings": [],
#   "id": "u7xtg8mj",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b17595770"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "1759577"
#     }
#   ],
#   "images": [],
#   "items": [
#     {
#       "id": null,
#       "identifiers": [],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "view-online",
#                 "label": "View online",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "licensed-resources",
#                 "label": "Licensed resources",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": null,
#           "license": null,
#           "linkText": "View online",
#           "locationType": {
#             "id": "online-resource",
#             "label": "Online resource",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "DigitalLocation",
#           "url": "https://www.proquest.com/eebo/docview/2240852944/shibboleth?accountid=14952"
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     }
#   ],
#   "languages": [
#     {
#       "id": "eng",
#       "label": "English",
#       "type": "Language"
#     }
#   ],
#   "lettering": null,
#   "notes": [
#     {
#       "contents": [
#         "Reproduction of original in the Bodleian Library."
#       ],
#       "noteType": {
#         "id": "general-note",
#         "label": "Notes",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "Wing A1454"
#       ],
#       "noteType": {
#         "id": "references-note",
#         "label": "References note",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "Electronic reproduction. Ann Arbor, Mich. : UMI, 1999- (Early English books online) Digital version of: (Early English books, 1641-1700 ; 1056:8) s1999    miun s"
#       ],
#       "noteType": {
#         "id": "reproduction-note",
#         "label": "Reproduction note",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     }
#   ],
#   "partOf": [
#     {
#       "id": null,
#       "partOf": null,
#       "referenceNumber": null,
#       "title": "Early English books online",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Series"
#     }
#   ],
#   "parts": [],
#   "physicalDescription": "48 unnumbered pages",
#   "precededBy": [],
#   "production": [
#     {
#       "agents": [
#         {
#           "label": "Printed by S.S. for the Company of Stationers",
#           "type": "Agent"
#         }
#       ],
#       "dates": [
#         {
#           "label": "1677",
#           "type": "Period"
#         }
#       ],
#       "function": null,
#       "label": "London : Printed by S.S. for the Company of Stationers, 1677.",
#       "places": [
#         {
#           "label": "London",
#           "type": "Place"
#         }
#       ],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": null,
#   "subjects": [
#     {
#       "concepts": [
#         {
#           "id": "dtqj5skq",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "lc-subjects",
#                 "label": "Library of Congress Subject Headings (LCSH)",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "sh86005784"
#             }
#           ],
#           "label": "Almanacs, English",
#           "type": "Concept"
#         }
#       ],
#       "id": "dtqj5skq",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "lc-subjects",
#             "label": "Library of Congress Subject Headings (LCSH)",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "sh86005784"
#         }
#       ],
#       "label": "Almanacs, English",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "rz2b24za",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "lc-subjects",
#                 "label": "Library of Congress Subject Headings (LCSH)",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "sh85044264"
#             }
#           ],
#           "label": "Ephemerides",
#           "type": "Concept"
#         }
#       ],
#       "id": "rz2b24za",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "lc-subjects",
#             "label": "Library of Congress Subject Headings (LCSH)",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "sh85044264"
#         }
#       ],
#       "label": "Ephemerides",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "bejypfcz",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "astrology"
#             }
#           ],
#           "label": "Astrology",
#           "type": "Concept"
#         },
#         {
#           "id": "pqf4m9zw",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "early works to 1800"
#             }
#           ],
#           "label": "Early works to 1800",
#           "type": "Concept"
#         }
#       ],
#       "id": "fd22k2kf",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "lc-subjects",
#             "label": "Library of Congress Subject Headings (LCSH)",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "sh2007100969"
#         }
#       ],
#       "label": "Astrology - Early works to 1800",
#       "type": "Subject"
#     }
#   ],
#   "succeededBy": [],
#   "thumbnail": null,
#   "title": "Nuncius coelestis, or, Urania's messenger : being a brief description and survey of the year of humane redemption 1677 : unto which is numbered ... : accomodated to the meridian of London ... / by Henry Coley.",
#   "type": "Work",
#   "workType": {
#     "id": "a",
#     "label": "Books",
#     "type": "Format"
#   }
# }

# %% [markdown]
# ## Work (Book) (locationType.id: `iiif-presentation`) (embedded PDF)
# - https://wellcomecollection.org/works/deybwyaf

# %%
print_json("deybwyaf")
# Out:
# {
#   "alternativeTitles": [
#     "Galen commentary on Hippocrates Epidemics book 1 parts I-III"
#   ],
#   "availabilities": [
#     {
#       "id": "online",
#       "label": "Online",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [
#     {
#       "agent": {
#         "id": "ch4dx5r2",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "lc-names",
#               "label": "Library of Congress Name authority records",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "n79059644"
#           }
#         ],
#         "label": "Galen",
#         "type": "Person"
#       },
#       "primary": true,
#       "roles": [
#         {
#           "label": "author",
#           "type": "ContributionRole"
#         }
#       ],
#       "type": "Contributor"
#     },
#     {
#       "agent": {
#         "id": "mx4zvzk6",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "lc-names",
#               "label": "Library of Congress Name authority records",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "no2006133710"
#           }
#         ],
#         "label": "Vagelpohl, Uwe",
#         "type": "Person"
#       },
#       "primary": false,
#       "roles": [
#         {
#           "label": "translator,",
#           "type": "ContributionRole"
#         },
#         {
#           "label": "writer of added commentary",
#           "type": "ContributionRole"
#         }
#       ],
#       "type": "Contributor"
#     },
#     {
#       "agent": {
#         "id": "ae94d67v",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "lc-names",
#               "label": "Library of Congress Name authority records",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "n80145641"
#           }
#         ],
#         "label": "\u1e24unayn ibn Is\u1e25\u0101q al-\u02bbIb\u0101d\u012b, 809?-873",
#         "type": "Person"
#       },
#       "primary": false,
#       "roles": [
#         {
#           "label": "translator",
#           "type": "ContributionRole"
#         }
#       ],
#       "type": "Contributor"
#     }
#   ],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": "<p>The present volume offers the first critical edition of Book 1 of the medieval Arabic translation of Galen's Commentary on the Hippocratic Epidemics, produced by the celebrated translator Hunayn ibn Ish\u0101q (d. ca. 870). The edition is based on all extant Arabic textual witnesses, including the Arabic secondary transmission.The translation of Galen's commentary became a crucial source for the development of medicine in the Islamic world, especially in the nascent field of clinical medicine. It was frequently read and quoted in later Arabic medical literature, and several Arabic authors used it to produce a wide range of didactic writings for medical students and practising physicians.The English translation, which aims to convey some of the flavour of the Arabic translation, comes with extensive notes on the differences between the Greek original and the Arabic translation. A thorough comparison between the two versions of the commentary provides important insights into the translation style and technique of Hunayn ibn Ish\u0101q and his circle and Arabic medical terminology at the time.</p>",
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [
#     {
#       "concepts": [
#         {
#           "id": "kqkakf66",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "electronic books"
#             }
#           ],
#           "label": "Electronic books",
#           "type": "Genre"
#         }
#       ],
#       "label": "Electronic books",
#       "type": "Genre"
#     }
#   ],
#   "holdings": [],
#   "id": "deybwyaf",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b28820757"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "2882075"
#     },
#     {
#       "identifierType": {
#         "id": "isbn",
#         "label": "International Standard Book Number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "9783110406597"
#     },
#     {
#       "identifierType": {
#         "id": "isbn",
#         "label": "International Standard Book Number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "3110406594"
#     }
#   ],
#   "images": [],
#   "items": [
#     {
#       "id": null,
#       "identifiers": [],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "view-online",
#                 "label": "View online",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "open",
#                 "label": "Open",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": null,
#           "license": {
#             "id": "cc-by-nc-nd",
#             "label": "Attribution-NonCommercial-NoDerivatives 4.0 International (CC BY-NC-ND 4.0)",
#             "type": "License",
#             "url": "https://creativecommons.org/licenses/by-nc-nd/4.0/"
#           },
#           "linkText": null,
#           "locationType": {
#             "id": "iiif-presentation",
#             "label": "IIIF Presentation API",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "DigitalLocation",
#           "url": "https://iiif.wellcomecollection.org/presentation/v2/b28820757"
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     }
#   ],
#   "languages": [],
#   "lettering": null,
#   "notes": [
#     {
#       "contents": [
#         "Includes bibliographical references and index."
#       ],
#       "noteType": {
#         "id": "bibliographic-info",
#         "label": "Bibliographic information",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "Text in English and Arabic."
#       ],
#       "noteType": {
#         "id": "language-note",
#         "label": "Language note",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "Description based on online resource; title from PDF title page (OAPEN, viewed July 8, 2016)."
#       ],
#       "noteType": {
#         "id": "general-note",
#         "label": "Notes",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     }
#   ],
#   "partOf": [],
#   "parts": [],
#   "physicalDescription": "1 online resource (736 pages)",
#   "precededBy": [],
#   "production": [
#     {
#       "agents": [
#         {
#           "label": "De Gruyter Akademie Forschung",
#           "type": "Agent"
#         }
#       ],
#       "dates": [
#         {
#           "label": "2014",
#           "type": "Period"
#         }
#       ],
#       "function": {
#         "label": "Publication",
#         "type": "Concept"
#       },
#       "label": "Berlin : De Gruyter Akademie Forschung, 2014.",
#       "places": [
#         {
#           "label": "Berlin",
#           "type": "Place"
#         }
#       ],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": null,
#   "subjects": [
#     {
#       "concepts": [
#         {
#           "id": "r6wmagke",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "medicine (general)"
#             }
#           ],
#           "label": "Medicine (General)",
#           "type": "Concept"
#         }
#       ],
#       "id": "r6wmagke",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "label-derived",
#             "label": "Identifier derived from the label of the referent",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "medicine (general)"
#         }
#       ],
#       "label": "Medicine (General)",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "b5sh23kc",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "epidemics"
#             }
#           ],
#           "label": "Epidemics",
#           "type": "Concept"
#         },
#         {
#           "id": "m7x7qxg6",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "history"
#             }
#           ],
#           "label": "history",
#           "type": "Concept"
#         }
#       ],
#       "id": "ksacfrt9",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D058872Q000266"
#         }
#       ],
#       "label": "Epidemics - history",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "maegwwt7",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "greek world"
#             }
#           ],
#           "label": "Greek World",
#           "type": "Concept"
#         },
#         {
#           "id": "m7x7qxg6",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "history"
#             }
#           ],
#           "label": "history",
#           "type": "Concept"
#         }
#       ],
#       "id": "vuhhhrp2",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D018645Q000266"
#         }
#       ],
#       "label": "Greek World - history",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "hka26xg3",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D049690"
#             }
#           ],
#           "label": "History, Ancient",
#           "type": "Concept"
#         }
#       ],
#       "id": "hka26xg3",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D049690"
#         }
#       ],
#       "label": "History, Ancient",
#       "type": "Subject"
#     }
#   ],
#   "succeededBy": [],
#   "thumbnail": {
#     "accessConditions": [],
#     "license": {
#       "id": "cc-by-nc-nd",
#       "label": "Attribution-NonCommercial-NoDerivatives 4.0 International (CC BY-NC-ND 4.0)",
#       "type": "License",
#       "url": "https://creativecommons.org/licenses/by-nc-nd/4.0/"
#     },
#     "locationType": {
#       "id": "thumbnail-image",
#       "label": "Thumbnail image",
#       "type": "LocationType"
#     },
#     "type": "DigitalLocation",
#     "url": "https://iiif.wellcomecollection.org/thumb/b28820757"
#   },
#   "title": "Galeni In Hippocratis Epidemiarum librum I commentariorum I-III : versionem Arabicam / edidit, in lingnam Anglican vertit, commentatus est Uwe Vagelpohl = Galen commentary on Hippocrates Epidemics book 1 parts I-III : edition of the Arabic version / with English translation and notes by Uwe Vagelpohl.",
#   "type": "Work",
#   "workType": {
#     "id": "a",
#     "label": "Books",
#     "type": "Format"
#   }
# }

# %% [markdown]
# # Works rows with item location url has "presentation"

# %%
items_filter = """
  exists(
    items, i ->
        exists(i.locations, l ->
            l.url LIKE '%/presentation/%')
  )
"""

df_works_w_presentation = spark.table("works").filter(
    F.expr(items_filter)
)

# %% [markdown]
# # Number of works with IIIF Presentations

# %%
df_works_w_presentation.count()

# %%
print(json.dumps(df_works_w_presentation.first().asDict(recursive=True), indent=2))
# Out:
# {
#   "alternativeTitles": [],
#   "availabilities": [
#     {
#       "id": "closed-stores",
#       "label": "Closed stores",
#       "type": "Availability"
#     },
#     {
#       "id": "online",
#       "label": "Online",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": null,
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [],
#   "holdings": [],
#   "id": "xjjnw2zf",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "calm-record-id",
#         "label": "Calm RecordIdentifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "c660fa26-3b12-4993-ae16-ff2a56e0aa87"
#     },
#     {
#       "identifierType": {
#         "id": "calm-ref-no",
#         "label": "Calm RefNo",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "SAEUG/D/100"
#     },
#     {
#       "identifierType": {
#         "id": "calm-altref-no",
#         "label": "Calm AltRefNo",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "SA/EUG/D.100"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b16235484"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "1623548"
#     },
#     {
#       "identifierType": {
#         "id": "wellcome-digcode",
#         "label": "Wellcome digcode",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "diggenetics"
#     },
#     {
#       "identifierType": {
#         "id": "mets",
#         "label": "METS",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b16235484"
#     }
#   ],
#   "images": [],
#   "items": [
#     {
#       "id": "rsefm6cn",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "sierra-system-number",
#             "label": "Sierra system number",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "i15452438"
#         },
#         {
#           "identifierType": {
#             "id": "sierra-identifier",
#             "label": "Sierra identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "1545243"
#         }
#       ],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "online-request",
#                 "label": "Online request",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "open",
#                 "label": "Open",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": "Closed stores",
#           "license": null,
#           "linkText": null,
#           "locationType": {
#             "id": "closed-stores",
#             "label": "Closed stores",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "PhysicalLocation",
#           "url": null
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     },
#     {
#       "id": null,
#       "identifiers": [],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "view-online",
#                 "label": "View online",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "open-with-advisory",
#                 "label": "Open with advisory",
#                 "type": "AccessStatus"
#               },
#               "terms": "Works in this archive created by or for the Eugenics Society are available under a CC-BY-NC licence. Please be aware that works in this archive created by other organisations and individuals are not covered under this licence, and you should obtain any necessary permissions before copying or adapting any such works.",
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": null,
#           "license": {
#             "id": "inc",
#             "label": "In copyright",
#             "type": "License",
#             "url": "http://rightsstatements.org/vocab/InC/1.0/"
#           },
#           "linkText": null,
#           "locationType": {
#             "id": "iiif-presentation",
#             "label": "IIIF Presentation API",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "DigitalLocation",
#           "url": "https://iiif.wellcomecollection.org/presentation/v2/b16235484"
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     }
#   ],
#   "languages": [],
#   "lettering": null,
#   "notes": [],
#   "partOf": [
#     {
#       "id": "cusbrrek",
#       "partOf": [
#         {
#           "id": "w4v5xdrn",
#           "partOf": null,
#           "referenceNumber": "SA/EUG",
#           "title": "Eugenics Society",
#           "totalDescendentParts": 1392,
#           "totalParts": 17,
#           "type": "Collection"
#         }
#       ],
#       "referenceNumber": "SA/EUG/D",
#       "title": "'General'",
#       "totalDescendentParts": 293,
#       "totalParts": 156,
#       "type": "Section"
#     }
#   ],
#   "parts": [],
#   "physicalDescription": "1 file",
#   "precededBy": [
#     {
#       "id": "tdh9se5y",
#       "referenceNumber": "SA/EUG/D.1",
#       "title": "Abortion",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ng967gqs",
#       "referenceNumber": "SA/EUG/D.2",
#       "title": "Advertisement for Volunteers",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "cux2r9p4",
#       "referenceNumber": "SA/EUG/D.3",
#       "title": "Advice and Enquiries",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "r779hejy",
#       "referenceNumber": "SA/EUG/D.4",
#       "title": "Advice and Enquiries",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "k96jjucw",
#       "referenceNumber": "SA/EUG/D.5",
#       "title": "Aims and Objects of the Society",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "emanm5c5",
#       "referenceNumber": "SA/EUG/D.6",
#       "title": "AID (Artificial Insemination by Donor)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "mbztscp9",
#       "referenceNumber": "SA/EUG/D.7",
#       "title": "AID (Artificial Insemination by Donor)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "hwtn6vep",
#       "referenceNumber": "SA/EUG/D.8",
#       "title": "Association for social and moral Hygiene",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ex34wc3z",
#       "referenceNumber": "SA/EUG/D.9",
#       "title": "The biochemical Society",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "mj3kj3tb",
#       "referenceNumber": "SA/EUG/D.10",
#       "title": "Biology and Social Work",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "x9gbuuf7",
#       "referenceNumber": "SA/EUG/D.11",
#       "title": "Biology in Schools",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "evvh9k3m",
#       "referenceNumber": "SA/EUG/D.12-41",
#       "title": "Birth Control",
#       "totalDescendentParts": 31,
#       "totalParts": 21,
#       "type": "Series"
#     },
#     {
#       "id": "rq7sgp7e",
#       "referenceNumber": "SA/EUG/D.42",
#       "title": "Board of Control",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "tmapk8b2",
#       "referenceNumber": "SA/EUG/D.43",
#       "title": "British Association for the Advancement of Science",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ndsft6as",
#       "referenceNumber": "SA/EUG/D.44",
#       "title": "British Broadcasting Association",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "s5ehmr4h",
#       "referenceNumber": "SA/EUG/D.45",
#       "title": "British Committee for Aiding Men of Letters and Science in Russia",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "sfnkvp4r",
#       "referenceNumber": "SA/EUG/D.46",
#       "title": "British Empire League",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "fdcdmyr3",
#       "referenceNumber": "SA/EUG/D.47",
#       "title": "British Medical Association",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "nugn8j4f",
#       "referenceNumber": "SA/EUG/D.48",
#       "title": "British Medical Journal: letter on sterility",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "tfxnjm6w",
#       "referenceNumber": "SA/EUG/D.49",
#       "title": "British Psychological Society",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "dvrrse99",
#       "referenceNumber": "SA/EUG/D.50",
#       "title": "Brock Report",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ghupertn",
#       "referenceNumber": "SA/EUG/D.51",
#       "title": "The Caldecott Community",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "r34h6mmr",
#       "referenceNumber": "SA/EUG/D.52",
#       "title": "Canada",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "zeh6um4t",
#       "referenceNumber": "SA/EUG/D.53",
#       "title": "Central Association for Mental Welfare",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "dx33k7zg",
#       "referenceNumber": "SA/EUG/D.54",
#       "title": "Charity Organisation Society",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "h5pkdwuy",
#       "referenceNumber": "SA/EUG/D.55",
#       "title": "Church Congress",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "w947mwut",
#       "referenceNumber": "SA/EUG/D.56",
#       "title": "City Temple Literary Society",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "kjyqta7e",
#       "referenceNumber": "SA/EUG/D.57",
#       "title": "College of Arms",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "xmwfeh9d",
#       "referenceNumber": "SA/EUG/D.58",
#       "title": "Copec (Christian Order in Politics Economics and Citizenship)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "axngwtq2",
#       "referenceNumber": "SA/EUG/D.59",
#       "title": "Cousin Marriage (Advice on) (C.O.C.)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "tnu97zj5",
#       "referenceNumber": "SA/EUG/D.60",
#       "title": "Darwin Research Fellowships and Studentships",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "rn88rj5k",
#       "referenceNumber": "SA/EUG/D.61",
#       "title": "Declining Population",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "jj88b2zm",
#       "referenceNumber": "SA/EUG/D.62",
#       "title": "Definition of Terms (Fertility)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "j5t7kq67",
#       "referenceNumber": "SA/EUG/D.63",
#       "title": "Divorce (`C.O.C.')",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "s6nv6c3u",
#       "referenceNumber": "SA/EUG/D.64",
#       "title": "Education",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "enkfewsu",
#       "referenceNumber": "SA/EUG/D.65",
#       "title": "Family Allowances",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "bxujs3sq",
#       "referenceNumber": "SA/EUG/D.66",
#       "title": "Family Relations Group",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "yjuk9nuj",
#       "referenceNumber": "SA/EUG/D.67",
#       "title": "Family Relations Group: minute book",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "sayd6gs3",
#       "referenceNumber": "SA/EUG/D.68",
#       "title": "Films: proposed propaganda films on eugenics",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "bps93umr",
#       "referenceNumber": "SA/EUG/D.69",
#       "title": "Foreign Countries: propaganda",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "k5gqvnq9",
#       "referenceNumber": "SA/EUG/D.70",
#       "title": "Free German Research (Journal for)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "qn45zjb8",
#       "referenceNumber": "SA/EUG/D.71-74",
#       "title": "From Generation to Generation (film)",
#       "totalDescendentParts": 4,
#       "totalParts": 4,
#       "type": "Series"
#     },
#     {
#       "id": "qnmjg9b5",
#       "referenceNumber": "SA/EUG/D.75",
#       "title": "Gallup Poll (on Eugenics)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "njajm9my",
#       "referenceNumber": "SA/EUG/D.76",
#       "title": "Galton: opening of laboratories, list of Galton lectures",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "vy3gxdzd",
#       "referenceNumber": "SA/EUG/D.77",
#       "title": "Galton Trust",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "v5rnkx46",
#       "referenceNumber": "SA/EUG/D.78",
#       "title": "Genetical Society",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "mygdbff5",
#       "referenceNumber": "SA/EUG/D.79",
#       "title": "Genetics Committee",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "w3aepmxg",
#       "referenceNumber": "SA/EUG/D.80",
#       "title": "Genetics Congress, Berlin 1927",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "p4xaz55z",
#       "referenceNumber": "SA/EUG/D.81",
#       "title": "Girl Guides",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "drxp66tv",
#       "referenceNumber": "SA/EUG/D.82",
#       "title": "Guild of Health",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "fhfjtn4p",
#       "referenceNumber": "SA/EUG/D.83",
#       "title": "Havelock Ellis Centenary",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ac73w7jd",
#       "referenceNumber": "SA/EUG/D.84",
#       "title": "Health Teaching in Schools",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "a4jxxq2z",
#       "referenceNumber": "SA/EUG/D.85",
#       "title": "Heredity",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "bqnvtrmq",
#       "referenceNumber": "SA/EUG/D.86",
#       "title": "Heredity Exhibit",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "k4prsdg5",
#       "referenceNumber": "SA/EUG/D.87",
#       "title": "Home and School Council",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "s2sbm7m6",
#       "referenceNumber": "SA/EUG/D.88",
#       "title": "Home Office",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "yvbezqpe",
#       "referenceNumber": "SA/EUG/D.89-97",
#       "title": "`Homes in Canada'",
#       "totalDescendentParts": 9,
#       "totalParts": 9,
#       "type": "Series"
#     },
#     {
#       "id": "zeuwwfzt",
#       "referenceNumber": "SA/EUG/D.98",
#       "title": "Human Affairs",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "sgaa5a7j",
#       "referenceNumber": "SA/EUG/D.99",
#       "title": "Human Evaluation",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     }
#   ],
#   "production": [
#     {
#       "agents": [],
#       "dates": [
#         {
#           "label": "1950",
#           "type": "Period"
#         }
#       ],
#       "function": null,
#       "label": "1950",
#       "places": [],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": "SA/EUG/D.100",
#   "subjects": [],
#   "succeededBy": [
#     {
#       "id": "dkdeanrb",
#       "referenceNumber": "SA/EUG/D.101",
#       "title": "Hundred New Towns Association",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "y6snbfwh",
#       "referenceNumber": "SA/EUG/D.102",
#       "title": "Hunterian Society (of St George's Hospital)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "xmpyppce",
#       "referenceNumber": "SA/EUG/D.103",
#       "title": "Immigration and Emigration",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "mbkkj7n3",
#       "referenceNumber": "SA/EUG/D.104",
#       "title": "Immigrants: research into",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "f3ek6tvb",
#       "referenceNumber": "SA/EUG/D.105",
#       "title": "Imperial Conference",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "fk3fypsf",
#       "referenceNumber": "SA/EUG/D.106",
#       "title": "Income Tax Amendments",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "bzfgrqmt",
#       "referenceNumber": "SA/EUG/D.107",
#       "title": "Incorporation",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "yhktd45k",
#       "referenceNumber": "SA/EUG/D.108",
#       "title": "Industrial Health Education Society (Inc)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "bpqcdv4s",
#       "referenceNumber": "SA/EUG/D.109",
#       "title": "International Eugenics Conferences (2nd 1921, 3rd 1932)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "mc322gwr",
#       "referenceNumber": "SA/EUG/D.110",
#       "title": "International Union for the Scientific Investigation of Population Problems",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "urpw7py3",
#       "referenceNumber": "SA/EUG/D.111",
#       "title": "International Union for the Scientific Investigation of Population Problems: papers of conference in Geneva",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "v5td9t3m",
#       "referenceNumber": "SA/EUG/D.112",
#       "title": "International Union of Family Organisations",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "g6mk87p5",
#       "referenceNumber": "SA/EUG/D.113",
#       "title": "International Union of Family Organisations",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "uksx7uy3",
#       "referenceNumber": "SA/EUG/D.114",
#       "title": "International Union of Family Organisations",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "naddep5v",
#       "referenceNumber": "SA/EUG/D.115",
#       "title": "Jubilee Dinner see also D. 253",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "bs69dzeh",
#       "referenceNumber": "SA/EUG/D.116",
#       "title": "Leicester Intelligence Survey; spring 1949",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "c67ghhrd",
#       "referenceNumber": "SA/EUG/D.117",
#       "title": "Leicestershire Insurance Committee (Eugenics Services)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "x4dbga6r",
#       "referenceNumber": "SA/EUG/D.118",
#       "title": "Malthusian League",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "bvmmu4dy",
#       "referenceNumber": "SA/EUG/D.119",
#       "title": "Marriage Certificates",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ztfv7vgn",
#       "referenceNumber": "SA/EUG/D.120",
#       "title": "Marriage Guidance Council",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "euvfz7wm",
#       "referenceNumber": "SA/EUG/D.121",
#       "title": "Mensa Interrogatory on Evolution and Eugenics",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ksagymsx",
#       "referenceNumber": "SA/EUG/D.122-128",
#       "title": "Migration Council",
#       "totalDescendentParts": 7,
#       "totalParts": 7,
#       "type": "Series"
#     },
#     {
#       "id": "bun9p3qz",
#       "referenceNumber": "SA/EUG/D.129",
#       "title": "Miscellaneous",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "p67yj3qk",
#       "referenceNumber": "SA/EUG/D.130",
#       "title": "Moscow International Congress of Genetics",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "v6dk6c9k",
#       "referenceNumber": "SA/EUG/D.131",
#       "title": "National Association for Mental Health",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "hjkuexvw",
#       "referenceNumber": "SA/EUG/D.132",
#       "title": "National Birthday Trust Fund",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "jxhe3syr",
#       "referenceNumber": "SA/EUG/D.133",
#       "title": "National Council for Mental Hygiene",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "k8dd4j9y",
#       "referenceNumber": "SA/EUG/D.134",
#       "title": "National Council of Women",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "aksbznd4",
#       "referenceNumber": "SA/EUG/D.135",
#       "title": "National Council of Women",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "n8d8mfpv",
#       "referenceNumber": "SA/EUG/D.136",
#       "title": "National Council of Women",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "xftfjjnj",
#       "referenceNumber": "SA/EUG/D.137",
#       "title": "National Federation of the Blind of the UK",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "bfh6e9rj",
#       "referenceNumber": "SA/EUG/D.138",
#       "title": "National Health",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ah8h2myu",
#       "referenceNumber": "SA/EUG/D.139",
#       "title": "National Institute of Economic and Social Research",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "k7huw463",
#       "referenceNumber": "SA/EUG/D.140",
#       "title": "National Life",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "t9p7qsb8",
#       "referenceNumber": "SA/EUG/D.141",
#       "title": "National Marriage Guidance Council",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "csrnqkuz",
#       "referenceNumber": "SA/EUG/D.142",
#       "title": "National Society for Lunacy Law Reform",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "kgh4ruvf",
#       "referenceNumber": "SA/EUG/D.143",
#       "title": "National Society for the Prevention of Cruelty to Children",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "h5hqhbhw",
#       "referenceNumber": "SA/EUG/D.144",
#       "title": "National Society for Women's Service",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "fpqbnpgm",
#       "referenceNumber": "SA/EUG/D.145",
#       "title": "National Special Schools Union",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "gc5q9yvq",
#       "referenceNumber": "SA/EUG/D.146",
#       "title": "National Temperance League",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "r5nr9298",
#       "referenceNumber": "SA/EUG/D.147",
#       "title": "National Union of Societies for Equal Citizenship",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "psxdwmub",
#       "referenceNumber": "SA/EUG/D.148",
#       "title": "National Union of Teachers",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "wbbvf3kr",
#       "referenceNumber": "SA/EUG/D.149",
#       "title": "National Union of Women Teachers",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "gdunzakh",
#       "referenceNumber": "SA/EUG/D.150",
#       "title": "National Workers Committee for the Legalising of Voluntary Sterilisation",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ya42hx2e",
#       "referenceNumber": "SA/EUG/D.151",
#       "title": "New Education Fellowship",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "hgpke9h5",
#       "referenceNumber": "SA/EUG/D.152",
#       "title": "New Health Society",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "pq5tcgv3",
#       "referenceNumber": "SA/EUG/D.153",
#       "title": "Nineteenth Century",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "sc47nptn",
#       "referenceNumber": "SA/EUG/D.154",
#       "title": "North Kensington Women's Marriage Welfare Centre",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "xm8n8utv",
#       "referenceNumber": "SA/EUG/D.155",
#       "title": "Nuffield Foundation",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "dr762yqt",
#       "referenceNumber": "SA/EUG/D.156",
#       "title": "Parents' National Educational Union",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "puc9dvwf",
#       "referenceNumber": "SA/EUG/D.157",
#       "title": "People's League of Health",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "qzb7abdb",
#       "referenceNumber": "SA/EUG/D.158",
#       "title": "Pioneer Health Centre, Peckham",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "c3yt8buq",
#       "referenceNumber": "SA/EUG/D.159",
#       "title": "Pioneer Health Centre, Peckham",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "jayj4npw",
#       "referenceNumber": "SA/EUG/D.160",
#       "title": "Population",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "hxxhqdsq",
#       "referenceNumber": "SA/EUG/D.161",
#       "title": "Population Investigation Committee",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "yt6stuup",
#       "referenceNumber": "SA/EUG/D.162",
#       "title": "Population Research",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "x5c4eyp6",
#       "referenceNumber": "SA/EUG/D.163",
#       "title": "Positive Eugenics",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "kfeh9ctm",
#       "referenceNumber": "SA/EUG/D.164",
#       "title": "Premarital Health Schedule (including individual enquiries)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "sd3kujzz",
#       "referenceNumber": "SA/EUG/D.165",
#       "title": "Premarital Health Schedule (including individual enquiries)",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "gntuzvnz",
#       "referenceNumber": "SA/EUG/D.166",
#       "title": "Premiers: India and Colonies",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ea3n3qh8",
#       "referenceNumber": "SA/EUG/D.167",
#       "title": "Press",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "fst4gchf",
#       "referenceNumber": "SA/EUG/D.168-173",
#       "title": "Problem Families (see also Social Problem Group)",
#       "totalDescendentParts": 7,
#       "totalParts": 4,
#       "type": "Series"
#     },
#     {
#       "id": "skngx63g",
#       "referenceNumber": "SA/EUG/D.174-175",
#       "title": "Promising Families",
#       "totalDescendentParts": 2,
#       "totalParts": 2,
#       "type": "Series"
#     },
#     {
#       "id": "m6q5qdfs",
#       "referenceNumber": "SA/EUG/D.176",
#       "title": "Propaganda",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "utws79e6",
#       "referenceNumber": "SA/EUG/D.177",
#       "title": "Public Morality Council",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "uj2j6kfg",
#       "referenceNumber": "SA/EUG/D.178",
#       "title": "Public Opinion Survey",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "q77nh84s",
#       "referenceNumber": "SA/EUG/D.179",
#       "title": "Race Crossing Investigation",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "cq23qqv3",
#       "referenceNumber": "SA/EUG/D.180",
#       "title": "Refugees",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "wgc6kysx",
#       "referenceNumber": "SA/EUG/D.181",
#       "title": "Research Committee: letters, etc",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "czjfwpxs",
#       "referenceNumber": "SA/EUG/D.182",
#       "title": "Right to Motherhood",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "txybpyqt",
#       "referenceNumber": "SA/EUG/D.183",
#       "title": "Rockefeller School of Hygiene",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "srpeb3xy",
#       "referenceNumber": "SA/EUG/D.184",
#       "title": "Royal Commission on Marriage and Divorce",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "y7samcnn",
#       "referenceNumber": "SA/EUG/D.185",
#       "title": "Royal Commission on Population",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "de9djrbm",
#       "referenceNumber": "SA/EUG/D.186",
#       "title": "Royal Commission on the Geographical Distribution of the industrial Population",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ah6tp6sq",
#       "referenceNumber": "SA/EUG/D.187",
#       "title": "Royal Institute of Public Health",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "y27aj9at",
#       "referenceNumber": "SA/EUG/D.188",
#       "title": "Royal Institution",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "yddc3y65",
#       "referenceNumber": "SA/EUG/D.189",
#       "title": "Royal Sanitary Institute",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "sehdcab4",
#       "referenceNumber": "SA/EUG/D.190",
#       "title": "Royal Society",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "uw9epb2n",
#       "referenceNumber": "SA/EUG/D.191",
#       "title": "Royal Society of Arts",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "w6cqnjr3",
#       "referenceNumber": "SA/EUG/D.192",
#       "title": "Royal Society of Medicine",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "kn28g53s",
#       "referenceNumber": "SA/EUG/D.193",
#       "title": "Royal Society of Medicine",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "m3hhc45n",
#       "referenceNumber": "SA/EUG/D.194",
#       "title": "Royal Statistical Society",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "z94cwzz3",
#       "referenceNumber": "SA/EUG/D.195-197",
#       "title": "Social Problem Group",
#       "totalDescendentParts": 3,
#       "totalParts": 3,
#       "type": "Series"
#     },
#     {
#       "id": "hwxzbnwa",
#       "referenceNumber": "SA/EUG/D.198",
#       "title": "Social Work Conferences",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "cf72umrg",
#       "referenceNumber": "SA/EUG/D.199",
#       "title": "The Syers Trust",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "yz7cqg5t",
#       "referenceNumber": "SA/EUG/D.200",
#       "title": "Vagrancy Reform Society",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "dbyapeqx",
#       "referenceNumber": "SA/EUG/D.201",
#       "title": "Voluntary Euthanasia Legalisation Society",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ypxxnt53",
#       "referenceNumber": "SA/EUG/D.202-203",
#       "title": "Voluntary Parenthood Society (John Strachey)",
#       "totalDescendentParts": 2,
#       "totalParts": 2,
#       "type": "Series"
#     },
#     {
#       "id": "dv47r54g",
#       "referenceNumber": "SA/EUG/D.204-247",
#       "title": "Voluntary Sterilisation",
#       "totalDescendentParts": 46,
#       "totalParts": 28,
#       "type": "Series"
#     },
#     {
#       "id": "v56cmd4b",
#       "referenceNumber": "SA/EUG/D.248",
#       "title": "Wartime",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "vsxjxyv8",
#       "referenceNumber": "SA/EUG/D.249",
#       "title": "Workers' Educational Association",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "ydnw25wr",
#       "referenceNumber": "SA/EUG/D.250",
#       "title": "World League for Sexual Reform",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "cbc82rsw",
#       "referenceNumber": "SA/EUG/D.251",
#       "title": "Tape recordings of evidence given to AID Investigation Council by Drs Barton, Bloom, Boyd, Chesser, Davidson, Jackson, Mears, Sandler, Shotton and Wright",
#       "totalDescendentParts": 18,
#       "totalParts": 18,
#       "type": "Series"
#     },
#     {
#       "id": "n2wkudp3",
#       "referenceNumber": "SA/EUG/D.252",
#       "title": "1st International Eugenics Congress: seating plan for banquet, photographs, cartoon by W K Hazeldon; later Eugenics Congresses - photographs",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "rnqf8zk7",
#       "referenceNumber": "SA/EUG/D.253",
#       "title": "Jubilee Dinner, 1957: photographs",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "pynkc2cn",
#       "referenceNumber": "SA/EUG/D.254-259",
#       "title": "Files received in 2009",
#       "totalDescendentParts": 8,
#       "totalParts": 3,
#       "type": "Section"
#     }
#   ],
#   "thumbnail": null,
#   "title": "Human Genetic Clinics",
#   "type": "Work",
#   "workType": {
#     "id": "h",
#     "label": "Archives and manuscripts",
#     "type": "Format"
#   }
# }

# %%
df_works_item_urls = (
    df_works_w_presentation
      # 1) explode each item so we have work‐level id + item struct
      .select(
          F.col("id"),
          F.explode(F.col("items")).alias("item")
      )
      # 2) from each item, explode only the locations whose URL matches
      .select(
          F.col("id"),
          F.col("item.id").alias("item_id"),
          F.explode(
              F.expr("filter(item.locations, l -> l.url LIKE '%/presentation/%')")
          ).alias("location")
      )
      # 3) pick out just the fields you want
      .select(
          F.col("id"),
          F.col("item_id"),
          F.col("location.url").alias("url")
      )
)

# %% [markdown]
# # Number of Presentation URLs

# %%
df_works_item_urls.count()
# Out:
# 338128

# %%
df_works_item_urls.show(truncate=False)
# Out:
# +--------+--------+-------------------------------------------------------------+
# |id      |item_id |url                                                          |
# +--------+--------+-------------------------------------------------------------+
# |xjjnw2zf|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b16235484|
# |t4rtqnma|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b22422547|
# |ukw5685u|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b29104956|
# |rjfdmzt4|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b29748859|
# |y6rya34t|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b2494628x|
# |c3782xby|gux39adm|https://iiif.wellcomecollection.org/presentation/v2/b28109892|
# |m3bpbasa|uk6jn3dr|https://iiif.wellcomecollection.org/presentation/v2/b24853367|
# |k89n5png|c45295z6|https://iiif.wellcomecollection.org/presentation/v2/b13134218|
# |xd8cw6mc|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b31497305|
# |ep3say76|uft6gtst|https://iiif.wellcomecollection.org/presentation/v2/b32754516|
# |d27t8ptw|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b21197702|
# |xcmh6wth|bv5pbtgu|https://iiif.wellcomecollection.org/presentation/v2/b24863373|
# |rzykqx3v|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b22376616|
# |pgejnas8|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b21113853|
# |yzpsxw3p|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b22341031|
# |hdbvy49t|tvdsd32x|https://iiif.wellcomecollection.org/presentation/v2/b33029775|
# |zstmqad5|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b29753557|
# |p4frywxp|fzdvhqvv|https://iiif.wellcomecollection.org/presentation/v2/b32814598|
# |zhk7jp6v|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b18536542|
# |edguseu9|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b28814952|
# +--------+--------+-------------------------------------------------------------+
# only showing top 20 rows

# %%
df_works_item_urls_subset = df_works_item_urls.sample(
    withReplacement=False,
    fraction=0.01,
    seed=42
)
df_works_item_urls_subset.count()
# Out:
# 3398

# %%
import requests
from pyspark.sql import functions as F
from pyspark.sql.types import StringType

# 1) UDF to fetch JSON text


def fetch_json(url: str) -> str:
    try:
        resp = requests.get(url, timeout=10)
        resp.raise_for_status()
        return resp.text
    except Exception:
        return None


fetch_json_udf = F.udf(fetch_json, StringType())

# -------------------------------------------------------
# Assume you already have `item_urls` from the previous step:
#   columns: work_id, item_id, url
# -------------------------------------------------------

# 2) Attach raw JSON string
with_json_str = (
    df_works_item_urls_subset
    .withColumn("json_str", fetch_json_udf(F.col("url")))
)

# 3) Infer schema once (optional; run this just one time)
raw_json_rdd = (
    with_json_str
    .select("json_str")
    .rdd
    .map(lambda r: r.json_str)
    .filter(lambda txt: txt is not None)
)
inferred_schema = spark.read.json(raw_json_rdd).schema

# 4) Parse into a Struct column, drop the raw text
result_df = (
    with_json_str
    .withColumn("json_data", F.from_json(F.col("json_str"), inferred_schema))
    .drop("json_str")
)

result_df.printSchema()
result_df.show(truncate=False)

# %%
result_df.schema
# Out:
# StructType([StructField('id', StringType(), True), StructField('item_id', StringType(), True), StructField('url', StringType(), True), StructField('json_data', StructType([StructField('@context', StringType(), True), StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('label', StringType(), True), StructField('license', StringType(), True), StructField('logo', StringType(), True), StructField('metadata', ArrayType(StructType([StructField('label', StringType(), True), StructField('value', StringType(), True)]), True), True), StructField('otherContent', ArrayType(StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('label', StringType(), True)]), True), True), StructField('related', StructType([StructField('@id', StringType(), True), StructField('format', StringType(), True), StructField('label', StringType(), True)]), True), StructField('seeAlso', StructType([StructField('@id', StringType(), True), StructField('format', StringType(), True), StructField('label', StringType(), True), StructField('profile', StringType(), True)]), True), StructField('sequences', ArrayType(StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('canvases', ArrayType(StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('height', LongType(), True), StructField('images', ArrayType(StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('motivation', StringType(), True), StructField('on', StringType(), True), StructField('resource', StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('format', StringType(), True), StructField('height', LongType(), True), StructField('service', StringType(), True), StructField('width', LongType(), True)]), True)]), True), True), StructField('label', StringType(), True), StructField('otherContent', ArrayType(StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('label', StringType(), True)]), True), True), StructField('seeAlso', StructType([StructField('@id', StringType(), True), StructField('format', StringType(), True), StructField('label', StringType(), True), StructField('profile', StringType(), True)]), True), StructField('thumbnail', StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('service', StructType([StructField('@context', StringType(), True), StructField('@id', StringType(), True), StructField('height', LongType(), True), StructField('profile', StringType(), True), StructField('protocol', StringType(), True), StructField('sizes', ArrayType(StructType([StructField('height', LongType(), True), StructField('width', LongType(), True)]), True), True), StructField('width', LongType(), True)]), True)]), True), StructField('width', LongType(), True), StructField('within', StringType(), True)]), True), True), StructField('label', StringType(), True), StructField('rendering', StringType(), True), StructField('viewingHint', StringType(), True)]), True), True), StructField('service', ArrayType(StructType([StructField('@context', StringType(), True), StructField('@id', StringType(), True), StructField('accessHint', StringType(), True), StructField('authService', StructType([StructField('@context', StringType(), True), StructField('@id', StringType(), True), StructField('confirmLabel', StringType(), True), StructField('description', StringType(), True), StructField('failureDescription', StringType(), True), StructField('failureHeader', StringType(), True), StructField('header', StringType(), True), StructField('label', StringType(), True), StructField('profile', StringType(), True), StructField('service', ArrayType(StructType([StructField('@context', StringType(), True), StructField('@id', StringType(), True), StructFiel ...

# %%
pages_df = result_df.withColumn(
    "pages",
    # grab the first element of the sequences array, then count its canvases
    F.expr("size(json_data.sequences[0].canvases)")
).select("id", "item_id", "url", "pages")

# %% [markdown]
# # Estimate number of scanned pages with a 1% sample

# %%
pages_df.agg(F.sum("pages")).show()
# Out:
# [Stage 74:====================================================>   (16 + 1) / 17]
# +----------+
# |sum(pages)|
# +----------+
# |    427656|
# +----------+

# %%
427656 / 0.01
# Out:
# 42765600.0

# %% [markdown]
# # Estimate number of scanned pages with a 0.1% sample

# %%
pages_df.agg(F.sum("pages")).show()
# Out:
# [Stage 66:====================================================>   (16 + 1) / 17]
# +----------+
# |sum(pages)|
# +----------+
# |     36511|
# +----------+

# %%
36511/0.001
# Out:
# 36511000.0
