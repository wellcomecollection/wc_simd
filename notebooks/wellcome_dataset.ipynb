# %%
from wc_simd.utility import spark_path

# %%
from pyspark.sql import SparkSession


spark = SparkSession.builder \
    .appName("test_pyspark") \
    .config("spark.driver.memory", "12g") \
    .config("spark.executor.memory", "12g") \
    .config("spark.sql.orc.enableVectorizedReader", "false") \
    .config("spark.sql.parquet.columnarReaderBatchSize", "1024") \
    .config("spark.sql.orc.columnarReaderBatchSize", "1024") \
    .getOrCreate()
spark.sparkContext.setLogLevel("ERROR")
spark
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/04/25 12:02:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ip-172-31-22-145.eu-west-2.compute.internal:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>test_pyspark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#spark.stop()

# %% [markdown]
# # Read and Partition Works JSON

# %%
df = spark.read.json(spark_path("../data/imports/works.json.gz"))

# %%
# Assume df is your existing PySpark DataFrame
n = 16  # Number of partitions you want

# Partition the DataFrame
df_repartitioned = df.repartition(n)

df_repartitioned.write.parquet(
    spark_path("../data/imports/works.parquet"),
    mode="overwrite")
# Out:
# 25/04/24 16:00:47 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
df_repartitioned = spark.read.parquet(spark_path("../data/imports/works.parquet"))

# %%
def count_in_partition(index, iterator):
    yield (index, sum(1 for _ in iterator))


partition_counts = df_repartitioned.rdd.mapPartitionsWithIndex(
    count_in_partition).collect()

for index, count in partition_counts:
    print(f"Partition {index}: {count} rows")
# Out:
# [Stage 1:=================================================>       (14 + 2) / 16]
# Partition 0: 72966 rows
# Partition 1: 72966 rows
# Partition 2: 72965 rows
# Partition 3: 72966 rows
# Partition 4: 72965 rows
# Partition 5: 72965 rows
# Partition 6: 72966 rows
# Partition 7: 72965 rows
# Partition 8: 72965 rows
# Partition 9: 72965 rows
# Partition 10: 72965 rows
# Partition 11: 72965 rows
# Partition 12: 72965 rows
# Partition 13: 72965 rows
# Partition 14: 72965 rows
# Partition 15: 72965 rows

# %%
df_repartitioned.printSchema()
# Out:
# root
#  |-- alternativeTitles: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- availabilities: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- contributors: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- agent: struct (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- identifiers: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- identifierType: struct (nullable = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- primary: boolean (nullable = true)
#  |    |    |-- roles: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- createdDate: struct (nullable = true)
#  |    |-- label: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- currentFrequency: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- designation: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- duration: long (nullable = true)
#  |-- edition: string (nullable = true)
#  |-- formerFrequency: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- genres: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- concepts: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- identifiers: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- identifierType: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- holdings: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- enumeration: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- location: struct (nullable = true)
#  |    |    |    |-- accessConditions: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- method: struct (nullable = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- status: struct (nullable = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- linkText: string (nullable = true)
#  |    |    |    |-- locationType: struct (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- shelfmark: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- note: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- identifiers: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- identifierType: struct (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- value: string (nullable = true)
#  |-- images: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- items: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- identifiers: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- identifierType: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- locations: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- accessConditions: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- method: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- note: string (nullable = true)
#  |    |    |    |    |    |    |-- status: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- terms: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- credit: string (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- license: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- linkText: string (nullable = true)
#  |    |    |    |    |-- locationType: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- shelfmark: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- note: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- languages: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- lettering: string (nullable = true)
#  |-- notes: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- contents: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- noteType: struct (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- partOf: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- partOf: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- partOf: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |-- partOf: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- partOf: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- partOf: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- partOf: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- partOf: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |    |    |-- totalParts: long (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |-- totalParts: long (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- parts: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |-- totalParts: long (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- physicalDescription: string (nullable = true)
#  |-- precededBy: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |-- totalParts: long (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- production: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- agents: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- dates: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- function: struct (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- places: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- referenceNumber: string (nullable = true)
#  |-- subjects: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- concepts: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- identifiers: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- identifierType: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- identifiers: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- identifierType: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- succeededBy: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- referenceNumber: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- totalDescendentParts: long (nullable = true)
#  |    |    |-- totalParts: long (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- thumbnail: struct (nullable = true)
#  |    |-- accessConditions: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- license: struct (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- locationType: struct (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- workType: struct (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- label: string (nullable = true)
#  |    |-- type: string (nullable = true)

# %%
df_repartitioned.show()
# Out:
# +--------------------+--------------------+--------------------+-----------+----------------+--------------------+-----------+--------+-------+---------------+--------------------+--------------------+--------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+----+--------------------+
# |   alternativeTitles|      availabilities|        contributors|createdDate|currentFrequency|         description|designation|duration|edition|formerFrequency|              genres|            holdings|      id|         identifiers|             images|               items|           languages|           lettering|               notes|              partOf|parts| physicalDescription|          precededBy|          production|referenceNumber|            subjects|         succeededBy|           thumbnail|               title|type|            workType|
# +--------------------+--------------------+--------------------+-----------+----------------+--------------------+-----------+--------+-------+---------------+--------------------+--------------------+--------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+----+--------------------+
# |[Cato. A tragedy,...|[{online, Online,...|                  []|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|                  []|[{[Full text avai...|c7dbdub3|[{{ebsco-alt-look...|                 []|                  []|                  []|                NULL|                  []|[{NULL, NULL, NUL...|   []|                NULL|                  []|[{[], [], NULL, ,...|           NULL|                  []|                  []|                NULL|Cato. A tragedy, ...|Work|{v, E-books, Format}|
# |[Orlando innamora...|[{online, Online,...|[{{r88uf8gp, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|                  []|[{[Full text avai...|h4q4fpbj|[{{ebsco-alt-look...|                 []|                  []|                  []|                NULL|                  []|[{NULL, NULL, NUL...|   []|                NULL|                  []|[{[], [], NULL, ,...|           NULL|                  []|                  []|                NULL|Orlando innamorat...|Work|{v, E-books, Format}|
# |                  []|[{closed-stores, ...|                  []|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|                  []|                  []|xjjnw2zf|[{{calm-record-id...|                 []|[{rsefm6cn, [{{si...|                  []|                NULL|                  []|[{cusbrrek, [{w4v...|   []|              1 file|[{tdh9se5y, SA/EU...|[{[], [{1950, Per...|   SA/EUG/D.100|                  []|[{dkdeanrb, SA/EU...|                NULL|Human Genetic Cli...|Work|{h, Archives and ...|
# |                  []|[{online, Online,...|[{{guzs2skt, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|[{[{kqkakf66, [{{...|                  []|t4rtqnma|[{{sierra-system-...|                 []|[{NULL, [], [{[{{...|[{fre, French, La...|                NULL|[{[Bibliographie:...|[{NULL, NULL, NUL...|   []|38 pages, 1 unnum...|                  []|[{[{Impr. Gustave...|           NULL|[{[{e3k695pe, [{{...|                  []|{[], {inc, In cop...|Du traitement de ...|Work|  {a, Books, Format}|
# |                  []|[{online, Online,...|[{{zx4jffpk, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|[{[{kqkakf66, [{{...|                  []|ukw5685u|[{{sierra-system-...|                 []|[{NULL, [], [{[{{...|[{eng, English, L...|                NULL|[{[This work is a...|                  []|   []|                NULL|                  []|[{[], [{1970, Per...|           NULL|[{[{d6jhgxuc, [{{...|                  []|{[], {cc-by, Attr...|[Report 1970] / M...|Work|  {a, Books, Format}|
# |                  []|[{open-shelves, O...|[{{pr88y5tn, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|                  []|                  []|nedbddvs|[{{sierra-system-...|                 []|[{cexfatjf, [{{si...|[{eng, English, L...|                NULL|[{[Includes bibli...|                  []|   []|xii, 181 pages ; ...|                  []|[{[{MIT Press, Ag...|           NULL|[{[{ca6uzan8, [{{...|                  []|                NULL|Consciousness : c...|Work|  {a, Books, Format}|
# |                  []|[{closed-stores, ...|[{{axrd6av9, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|                  []|                  []|rru7hxhj|[{{sierra-system-...|                 []|[{agzqmbka, [{{si...|[{eng, English, L...|                NULL|[{[Copy 1 Note: E...|[{NULL, NULL, NUL...|   []|lxxvii, 146 leave...|                  []|[{[{Stockholm Uni...|           NULL|[{[{bxnk8vxn, [{{...|                  []|                NULL|The Boke of March...|Work|  {a, Books, Format}|
# |[Proposals for pr...|[{online, Online,...|[{{k7ugc5tu, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|                  []|[{[Full text avai...|u23tytgd|[{{ebsco-alt-look...|                 []|                  []|                  []|                NULL|                  []|[{NULL, NULL, NUL...|   []|                NULL|                  []|[{[], [], NULL, ,...|           NULL|                  []|                  []|                NULL|Proposals for pri...|Work|{v, E-books, Format}|
# |                  []|[{closed-stores, ...|                  []|       NULL|            NULL|Published anonymo...|         []|    NULL|   NULL|             []|                  []|                  []|t3qjzzua|[{{calm-record-id...|                 []|[{zhaprwpn, [{{si...|                  []|                NULL|                  []|[{dmgcmdjf, [{nwk...|   []|              1 file|[{f2qusdak, PP/SM...|[{[], [{1981, Per...|   PP/SML/D/2/9|                  []|[{bqgtpccg, PP/SM...|                NULL|"Thalidomide: 20 ...|Work|{h, Archives and ...|
# |[Substance of the...|[{online, Online,...|[{{af4drk3r, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|                  []|[{[Full text avai...|n4b69uu4|[{{ebsco-alt-look...|                 []|                  []|                  []|                NULL|                  []|[{NULL, NULL, NUL...|   []|                NULL|                  []|[{[], [], NULL, ,...|           NULL|                  []|                  []|                NULL|Substance of the ...|Work|{v, E-books, Format}|
# |[Lieut. James Moo...|[{online, Online,...|[{{ca267t23, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|                  []|[{[Full text avai...|dpev5ces|[{{ebsco-alt-look...|                 []|                  []|                  []|                NULL|                  []|[{NULL, NULL, NUL...|   []|                NULL|                  []|[{[], [], NULL, ,...|           NULL|                  []|                  []|                NULL|Lieut. James Mood...|Work|{v, E-books, Format}|
# |                  []|[{closed-stores, ...|[{{b4r46rym, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|[{[{hjzzh4gd, [{{...|                  []|c2p9k8pq|[{{sierra-system-...|[{r2afcudp, Image}]|[{m7frfz26, [{{si...|[{eng, English, L...|Training Institut...|[{[Wellcome Colle...|                  []|   []|1 print : wood en...|                  []|[{[], [], NULL, [...|         15606i|[{[{zqa4hrbz, [{{...|                  []|{[], {pdm, Public...|The front and bac...|Work|{k, Pictures, For...|
# |                  []|[{online, Online,...|[{{sn4t7cwk, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|[{[{kqkakf66, [{{...|                  []|rjfdmzt4|[{{sierra-system-...|                 []|[{NULL, [], [{[{{...|[{eng, English, L...|                NULL|[{[This work is a...|                  []|   []|                NULL|                  []|[{[], [{1958, Per...|           NULL|[{[{d6jhgxuc, [{{...|                  []|{[], {cc-by, Attr...|[Report 1958] / M...|Work|  {a, Books, Format}|
# |                  []|[{closed-stores, ...|[{{v6h66bvu, [{{l...|       NULL|            NULL|<p>The young fox ...|         []|    NULL|   NULL|             []|[{[{vtqp967d, [{{...|                  []|stqfdfwf|[{{sierra-system-...|[{km2xn453, Image}]|[{d8uwnq3u, [{{si...|[{eng, English, L...|Reynard the fox. ...|[{[Wellcome Colle...|                  []|   []|1 print : steel e...|                  []|[{[{William Picke...|         39617i|[{[{vh4m4har, [{{...|                  []|{[], {pdm, Public...|Inside the fox's ...|Work|{k, Pictures, For...|
# |                  []|[{online, Online,...|                  []|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|                  []|                  []|y6rya34t|[{{calm-record-id...|                 []|[{NULL, [], [{[{{...|                  []|                NULL|[{[Open and avail...|[{fruyumj7, [{q58...|   []|              1 file|[{dpmm83ns, RET/4...|[{[], [{1924 - 19...|    RET/4/3/4/2|                  []|                  []|                NULL|        File on Food|Work|{h, Archives and ...|
# |                  []|[{closed-stores, ...|[{{xyezsmft, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|2nd ed.|             []|                  []|                  []|c3782xby|[{{sierra-system-...|                 []|[{gux39adm, [{{si...|[{eng, English, L...|                NULL|[{[Also published...|                  []|   []|xvii, 436 pages, ...|                  []|[{[{Hodder & Stou...|           NULL|                  []|                  []|{[], {pdm, Public...|The unconscious m...|Work|  {a, Books, Format}|
# |                  []|[{closed-stores, ...|[{{yumm8zf3, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|                  []|                  []|m3bpbasa|[{{sierra-system-...|                 []|[{uk6jn3dr, [{{si...|[{ger, German, La...|                NULL|[{[Text in German...|                  []|   []|135 pages : illus...|                  []|[{[], [{[pref. 19...|           NULL|                  []|                  []|{[], {inc, In cop...|Das chemische Lab...|Work|  {a, Books, Format}|
# |                  []|[{closed-stores, ...|                  []|       NULL|            NULL|Contains Volume 1...|         []|    NULL|   NULL|             []|                  []|                  []|bpqshyvr|[{{calm-record-id...|                 []|[{sjdy5k9e, [{{si...|                  []|                NULL|[{[Compiled by th...|[{esktx255, [{zj4...|   []|              1 file|[{pu9emmet, PSY/Y...|[{[], [{1984-1985...|  PSY/YAT/3/1/4|                  []|[{xuyje9ee, PSY/Y...|                NULL|<i>Behavioral Psy...|Work|{h, Archives and ...|
# |                  []|[{closed-stores, ...|[{{w7xcekc5, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|[{[{byh7nvvz, [{{...|                  []|k89n5png|[{{sierra-system-...|                 []|[{c45295z6, [{{si...|[{ger, German, La...|                NULL|[{[Second part of...|                  []|   []|12 unnumbered pag...|                  []|[{[{Durch Nicolau...|           NULL|[{[{cbdwjshh, [{{...|                  []|                NULL|[Melitsaḥ] kai he...|Work|  {a, Books, Format}|
# |                  []|[{online, Online,...|                  []|       NULL|            NULL|                NULL|         []|    NULL|   NULL|             []|                  []|                  []|j9xvn75t|[{{miro-image-num...|[{m4bcgrza, Image}]|[{NULL, [], [{[{{...|                  []|                NULL|                  []|                  []|   []|                NULL|                  []|                  []|           NULL|                  []|                  []|{[], {pdm, Public...|Front page of the...|Work|{q, Digital Image...|
# +--------------------+--------------------+--------------------+-----------+----------------+--------------------+-----------+--------+-------+---------------+--------------------+--------------------+--------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+----+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Save Works table

# %%
df_repartitioned.write.saveAsTable("works")
# Out:
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.dump.metadata.only.for.external.table does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.druid.rollup does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.retain.prev.dump.dir does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.log.explain.output.to.console does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.wm.delayed.move.timeout does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.privilege.synchronizer does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.wm.default.pool.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.task.scheduler.preempt.independent does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.cvb.memory.consumption. does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.output.format.arrow does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.llap.min.reducer.per.executor does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.path.cache.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.arrow.root.allocator.limit does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.topnkey.max does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.splits.available.slots.calculator.class.name does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.vectorized.use.checked.expressions does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.delete.metadata.only does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.filter.preds.sort does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.wait.timeout does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.nodehealthchecks.executorratio does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.transform.in.maxnodes does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.parquet.date.proleptic.gregorian.default does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.security.authorization.functions.in.view does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.saml2.sign.requests does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.dynamic.semijoin.reduction.for.mapjoin does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.metadata.query.cache.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.test.fail.load.dynamic.partition does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.cli.tez.initialize.session does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.vectorized.complex.types.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.wm.worker.threads does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.wm.delayed.move does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.daemon.umbilical.port does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.saml2.callback.token.ttl does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.partitions.dump.parallelism does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.thrift.client.max.message.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.uri.selection does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.strict.checks.no.partition.filter does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.datetime.formatter does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.dynamic.semijoin.reduction.for.dpp.factor does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.materializedview.rewriting.sql does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.delayed.cleanup.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.filter.in.min.ratio does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.shared.work.downstream.merge does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.webui.xframe.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.retry.total.duration does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.client.cache.initial.capacity does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.hook.proto.file.per.event does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.worker.sleep.time does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.daemon.web.xframe.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.ndv.estimate.percent does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.webui.cors.allowed.methods does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.joinreducededuplication does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.dynamic.partition.pruning.extended does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.estimators.enable does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.cume_dist.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.client.cache.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.scheduled.queries.executor.progress.report.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.test.acid.key.index.skip does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.fetch.bitvector does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.disable.unsafe.external.table.operations does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.materializedview.rewriting.incremental does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.materializedviews.registry.impl does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.etl.skip.format does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.event.db.notification.api.auth does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.exec.orc.delta.streaming.optimizations.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.shared.work.dppunion.merge.eventops does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.ndv.algo does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.udtf.factor does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.task.scheduler.am.collect.daemon.metrics.ms does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.filter.range.uniform does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.msck.repair.batch.max.retries does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.load.partitions.batch.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.update.table.properties.from.serde.list does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.zookeeper.killquery.enable does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.acid.metrics.max.cache.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.zookeeper.ssl.client.enable does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.aborted.txn.time.threshold does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.lock.file.move.protect does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.acid.lockless.reads.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.webui.max.graph.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.plugin.client.num.threads does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.test.bucketcodec.version does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.write.acid.version.file does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.materializedview.rewriting.time.window does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.reexecution.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.reexecution.stats.cache.batch.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.small.delta.dir.threshold does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.map.aggr.hash.flush.size.percent does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.countdistinct.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.webui.cors.allowed.headers does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.daemon.metrics.timed.window.average.data.points does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.avro.timestamp.write.legacy.conversion.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.join.inner.residual does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.active.passive.ha.enable does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.trace.always.dump does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.hdfs.package.dir does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.reexecution.stats.persist.scope does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.xlock.ctas does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.ctas.external.tables does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.mm.allow.originals does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.shared.work.merge.ts.schema does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.scheduled.queries.create.as.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.compact.insert.only does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.ranger.client.read.timeout does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.avro.proleptic.gregorian does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.load.dynamic.partitions.scan.specific.partitions does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.write.notification.max.batch.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.xlock.iow does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.lineage.hook.info.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.test.load.utilization does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.cache.defaultfs.only.native.fileid does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.saml2.want.assertions.signed does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.ha.datapath.replace.remote.nameservice does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.operation.log.purgePolicy.timeToLive does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.kerberos.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.testing.remove.logs does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.distcp.privileged.doAs does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.strict.checks.orderby.no.limit does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.cbo.stats.correlated.multi.key.joins does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.table.dump.parallelism does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.explain.node.visit.limit does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.client.cache.expiry.time does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.async.cleanup.service.queue.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.allocator.defrag.headroom does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.notification.event.consumers does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.iceberg.mask.default.location does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.vectorized.input.format.supports.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.client.cache.max.capacity does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.crud.query.based does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.hook.proto.events.ttl does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.request.queue does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.wm.namespace does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.max.concurrent.requests.per.daemon does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.client.cache.v2.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.parquet.timestamp.write.legacy.conversion.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.nodehealthchecks.minintervalduration does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.external.client.cloud.rpc.port does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.include.authorization.metadata does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.cache.hydration.save.dir does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.parallel.copy.tasks does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.external.warehouse.single.copy.task does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.webui.use.pam does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.ptf.valuecache.collect.statistics does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.reexecution.max.count does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.update.table.properties.from.serde does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.share.object.pools does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.service.metrics.codahale.reporter.classes does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.cleaner.duration.update.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.session.events.print.summary does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.security.hbase.urlencode.authorization.uri does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.acid.meta.columns does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.cume_dist.sketch does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.daemon.metrics.timed.window.average.window.length does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.mm.avoid.s3.globstatus does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.externaltable.snapshotdiff.copy does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.replica.functions.root.dir does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.avro.timestamp.legacy.conversion.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.results.cache.max.entry.lifetime does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.fetch.task.caching does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.limit.connections.per.user does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.shared.work.parallel.edge.support does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.sort.dynamic.partition.threshold does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.thrift.http.compression.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.split.update does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.strict.managed.tables does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.limit does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.rank.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.vectorized.execution.ptf.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.shared.work.extended does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.vectorized.row.identifier.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.reexecution.always.collect.operator.stats does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.worker.max.sleep.time does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.ntile.sketch does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.historic.operation.log.check.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.cte.materialize.full.aggregate.only does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.nonacid.read.locks does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.exec.use.fqdn does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.local.time.zone does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.tez.wm.am.registry.timeout does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.lrfu.hotbuffers.percentage does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.active.passive.ha.registry.namespace does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.create.as.insert.only does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.bootstrap.external.tables does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.mapjoin.memory.oversubscribe.factor does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.arrow.batch.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.operation.log.fetch.maxBytes does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.shared.work.dppunion does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.notification.sequence.lock.retry.sleep.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.parquet.date.proleptic.gregorian does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.security.authorization.scheduled.queries.supported does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.approx.max.load.tasks does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.results.cache.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.legacy.schema.for.all.serdes does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.include.external.tables does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.nodehealthchecks.mintasks does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.dag.status.check.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.external.table.purge.default does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.druid.bitmap.type does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.exec.orc.blob.storage.split.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.exec.orc.writer.llap.memory.manager.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.filter.transactions does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.externaltable.snapshot.overwrite.target does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.extend.bucketid.range does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.ntile.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.daemon.delegation.token.renew.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.memory.oversubscription.max.executors.per.query does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compute.splits.num.threads does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.concatenate.external.table does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.vectorized.execution.filesink.arrow.native.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.shared.work.semijoin does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.trace.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.planmapper.link.relnodes does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.kudu.master.addresses.default does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.plugin.rpc.num.handlers does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.test.load.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.wm.allow.any.pool.via.jdbc does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.async.cleanup.service.thread.count does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.batch.incremental.events does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.dump.skip.immutable.data.copy does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.ranger.target.deny.policy does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.vectorized.groupby.complex.types.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.avro.timestamp.skip.conversion does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.proactive.eviction.instant.dealloc does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.cbo.fallback.strategy does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.results.cache.nontransactional.tables.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.log.explain.output.include.extended does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.correlated.multi.key.joins does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.active.delta.dir.threshold does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.db.type does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.acid.dir.cache.duration does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.acid.metrics.logger.frequency does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.iceberg.allow.datafiles.in.table.location.only does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.streaming.auto.flush.check.interval.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.materializedview.rewriting.sql.subquery does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.ranger.use.fully.qualified.url does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.lrfu.bp.wrapper.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.iceberg.metadata.generator.threads does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.map.aggr.hash.min.reduction.stats does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.zookeeper.connection.timeout does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.reexecution.strategies does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.client.cache.v2.maxSize does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.daemon.metrics.simple.average.data.points does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.limit.connections.per.user.ipaddress does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.scheduled.queries.namespace does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.ext.locking.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.split.grouping.mode does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.acid.metrics.delta.pct.threshold does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.include.materialized.views does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.topnkey.efficiency.check.nbatches does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.mapjoin.memory.monitor.check.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.shared.work does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.clustered.sort does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.estimate does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.proactive.eviction.sweep.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.retry.max.delay.between.retries does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.ppd.recognize.column.equalities does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.webui.show.graph does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.failover.start does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.allocator.discard.method does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.cartesian-product.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.split.location.provider.class does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.notification.sequence.lock.max.retries does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.heap.memory.monitor.usage.threshold does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.encode.threadpool.multiplier does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.include.atlas.metadata does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.cleaner.threads.num does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.privilege.synchronizer.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.create.as.external.legacy does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.use.scratchdir.for.staging does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.vectorized.adaptor.suppress.evaluate.exceptions does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.allocator.preallocate does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.materializedview.rebuild.incremental does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.lockmetrics.collect does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.masking.algo does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.results.cache.max.entry.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.mapred.job.follow.tez.queue does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.testing.short.logs does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.external.client.use.hybrid.calendar does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.parquet.timestamp.legacy.conversion.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.druid.kerberos.enable does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.webui.xframe.value does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.saml2.max.authentication.lifetime does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.driver.parallel.compilation.global.limit does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.mapreduce.output.committer.class does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.stats.events.count does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.streaming.auto.flush.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.syslog.input.format.file.pruning does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.hdfs.encryption.shim.cache.on does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.shared.work.mapjoin.cache.reuse does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.parquet.write.int64.timestamp does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.percentile_disc.sketch does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.acid.createtable.softdelete does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.gather.stats does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.describe.partitionedtable.ignore.stats does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.xprod.mapjoin.small.table.rows does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.retain.prev.dump.dir.count does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.exec.dynamic.partition.type.conversion does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.read.locks does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.initiator.duration.update.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.operation.log.cleanup.delay does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.kll.enable does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.dynamic.semijoin.reduction.multicolumn does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.zookeeper.kerberos.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.run.data.copy.tasks.on.target does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.dump.metadata.only does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.webui.show.stats does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.countdistinct does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.daemon.web.xframe.value does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.client.cache.v2.recordStats does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.graceful.stop.timeout does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.jdbc.pushdown.safe.enable does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.union.flatten.subdirectories does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.xlock.mergeinsert does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.retain.custom.db.locations.on.target does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.auto.convert.join.shuffle.max.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.materializedview.rebuild.incremental.factor does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.plugin.acl does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.scheduled.queries.max.executors does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.authorization.provider.service does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.external.client.connect.timeout does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.schema.info.class does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.stats.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.kll.k.param does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.create.as.acid does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.auto.reducer.parallelism.min.threshold does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.parquet.infer.binary.as does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.handle.ranger.deny.policy does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.tez.queue.access.check does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.row.wrapper.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.external.splits.temp.table.storage.format does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.proactive.eviction.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.avro.proleptic.gregorian.default does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.join.ndv.readjustment does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.use.bitvectors does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.constraint.notnull.enforce does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.materializedviews.registry.refresh.period does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.unordered.output.buffer.size.mb does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.csrf.filter.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.task.time.print.summary does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.syslog.input.format.file.time.slice does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.nodehealthchecks.maxnodes does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.cli.print.escape.crlf does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.trigger.validation.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.hook.proto.rollover-interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.transpose.aggr.join.unique does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.historic.operation.log.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compaction.merge.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.retry.jitter does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.webui.cors.allowed.origins does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.limit.connections.per.ipaddress does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.cache.deletedeltas does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.acid.truncate.usebase does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.bootstrap.acid.tables does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.obsolete.delta.dir.threshold does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.bi.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.security.authorization.kerberos.use.shortname does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.iceberg.expire.snapshot.numthreads does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.client.cache.stats.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.mapjoin.hashtable.load.threads does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.scheduled.queries.executor.idle.sleep.time does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.notification.event.poll.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.transactional.concatenate.noblock does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.join.disjunctive.transitive.predicates.pushdown does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.iceberg.stats.source does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.materializedview.rewriting.strategy does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.vrb.queue.limit.max does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.rewrite.data.policy does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.default.nulls.last does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.acid.direct.insert.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.mr.compactor.gather.stats does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.vectorized.if.expr.mode does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.atlas.client.read.timeout does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.exim.test.mode does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.trusted.domain.use.xff.header does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.results.cache.directory does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.compactor.cleaner.retention.time.seconds does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.allocator.max.force.eviction does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.acid.metrics.delta.num.threshold does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.retrysnapshot.max.count does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.topnkey does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.load.partitions.with.data.copy.batch.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.nodehealthchecks.tasktimeratio does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.results.cache.wait.for.pending.results does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.bloom.filter.merge.threads does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.external.client.cloud.deployment.setup.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.join.shortcut.unmatched.rows does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.recompilation.max.count does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.datetime.formatter.resolver.style does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.remove.orderby.in.subquery does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.arrow.batch.allocator.limit does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.topnkey.partitions.max does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.cache.only does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.tez.bmj.use.subcache does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.acid.metrics.obsolete.delta.num.threshold does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.max.length does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.delete.all does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.wm.delayed.move.validator.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.percentile_disc.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.vrb.queue.limit.min does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.wm.pool.metrics does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.ptf.valuecache.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.external.client.cloud.jwt.shared.secret.provider does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.xlock.write does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.retry.backoff.coefficient does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.add.raw.reserved.namespace does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.jdbc.pushdown.enable does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.acid.droppartition.usebase does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.resource.use.hdfs.location does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.saml2.sp.force.auth does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.parquet.timestamp.time.unit does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.num.nulls.estimate.percent does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.rank.sketch does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.cm.encryptionzone.rootdir does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.use.googleregex.engine does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.ptf.rangecache.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.acid does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.bootstrap.dump.abort.write.txn.after.timeout does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.external.client.cloud.output.service.port does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.filter.delete.events does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.zk.sm.session.timeout does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.scheduled.queries.executor.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.load.data.use.native.api does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.vectorized.ptf.max.memory.buffering.batch.count does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.countdistinct.sketch does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.task.scheduler.am.registry does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.druid.overlord.address.default does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.remove.sq_count_check does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.map.aggr.hash.min.reduction.lower.bound does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.basic.stats.max.threads.factor does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.webui.enable.cors does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.acid.renamepartition.makecopy does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.constraints.join does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.vectorized.row.serde.inputformat.excludes does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.locks.max.partitions does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.reexecution.stats.cache.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.strict.checks.offset.no.orderby does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.readonly.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.hook.proto.queue.capacity does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.view.tables.cache.enabled does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.scan.probedecode does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.security.authorization.tables.on.storagehandlers does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.show.operation.drilldown.link does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.txn.acid.metrics.reporting.interval does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.zookeeper.killquery.namespace does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.copy.file.list.iterator.retry does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.optimize.topnkey.efficiency.threshold does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.webui.explain.output does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.plugin.rpc.port does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.lock.query.string.max.length does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.track.cache.usage does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.authentication.jwt.jwks.skip.ssl.cert does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.retry.initial.delay does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.hook.proto.events.clean.freq does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.use.orc.codec.pool does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.query.results.cache.max.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.auto.convert.anti.join does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.strict.timestamp.conversion does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.bootstrap.dump.open.txn.timeout does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.cardinality.preserving.join.optimization.factor does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.stats.max.num.stats does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.mapjoin.full.outer does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.dump.metadata.only.for.external.table does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.druid.rollup does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.repl.retain.prev.dump.dir does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.log.explain.output.to.console does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.server2.wm.delayed.move.timeout does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.privilege.synchronizer does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.metastore.wm.default.pool.size does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.task.scheduler.preempt.independent does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.output.format.arrow does not exist
# 25/04/25 11:42:04 WARN HiveConf: HiveConf of name hive.llap.io.cvb.memory.consumption. does not exist
# ...
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.webui.show.stats does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.countdistinct does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.daemon.web.xframe.value does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.metastore.client.cache.v2.recordStats does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.graceful.stop.timeout does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.jdbc.pushdown.safe.enable does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.tez.union.flatten.subdirectories does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.txn.xlock.mergeinsert does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.retain.custom.db.locations.on.target does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.auto.convert.join.shuffle.max.size does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.materializedview.rebuild.incremental.factor does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.plugin.acl does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.scheduled.queries.max.executors does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.authorization.provider.service does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.external.client.connect.timeout does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.metastore.schema.info.class does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.txn.stats.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.stats.kll.k.param does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.create.as.acid does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.tez.auto.reducer.parallelism.min.threshold does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.parquet.infer.binary.as does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.handle.ranger.deny.policy does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.tez.queue.access.check does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.external.splits.temp.table.storage.format does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.io.row.wrapper.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.io.proactive.eviction.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.avro.proleptic.gregorian.default does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.stats.join.ndv.readjustment does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.stats.use.bitvectors does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.constraint.notnull.enforce does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.tez.unordered.output.buffer.size.mb does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.materializedviews.registry.refresh.period does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.csrf.filter.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.task.time.print.summary does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.syslog.input.format.file.time.slice does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.nodehealthchecks.maxnodes does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.cli.print.escape.crlf does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.trigger.validation.interval does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.hook.proto.rollover-interval does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.transpose.aggr.join.unique does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.historic.operation.log.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.compaction.merge.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.retry.jitter does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.webui.cors.allowed.origins does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.limit.connections.per.ipaddress does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.io.cache.deletedeltas does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.acid.truncate.usebase does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.bootstrap.acid.tables does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.compactor.obsolete.delta.dir.threshold does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.bi.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.security.authorization.kerberos.use.shortname does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.iceberg.expire.snapshot.numthreads does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.metastore.client.cache.stats.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.mapjoin.hashtable.load.threads does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.scheduled.queries.executor.idle.sleep.time does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.notification.event.poll.interval does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.transactional.concatenate.noblock does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.join.disjunctive.transitive.predicates.pushdown does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.iceberg.stats.source does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.materializedview.rewriting.strategy does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.io.vrb.queue.limit.max does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.rewrite.data.policy does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.acid.direct.insert.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.default.nulls.last does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.mr.compactor.gather.stats does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.vectorized.if.expr.mode does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.atlas.client.read.timeout does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.exim.test.mode does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.trusted.domain.use.xff.header does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.query.results.cache.directory does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.compactor.cleaner.retention.time.seconds does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.io.allocator.max.force.eviction does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.txn.acid.metrics.delta.num.threshold does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.txn.retrysnapshot.max.count does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.topnkey does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.load.partitions.with.data.copy.batch.size does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.nodehealthchecks.tasktimeratio does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.query.results.cache.wait.for.pending.results does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.tez.bloom.filter.merge.threads does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.external.client.cloud.deployment.setup.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.join.shortcut.unmatched.rows does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.query.recompilation.max.count does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.datetime.formatter.resolver.style does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.remove.orderby.in.subquery does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.arrow.batch.allocator.limit does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.topnkey.partitions.max does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.io.cache.only does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.tez.bmj.use.subcache does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.txn.acid.metrics.obsolete.delta.num.threshold does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.query.max.length does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.delete.all does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.wm.delayed.move.validator.interval does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.percentile_disc.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.io.vrb.queue.limit.min does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.wm.pool.metrics does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.ptf.valuecache.size does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.external.client.cloud.jwt.shared.secret.provider does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.txn.xlock.write does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.retry.backoff.coefficient does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.add.raw.reserved.namespace does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.jdbc.pushdown.enable does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.acid.droppartition.usebase does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.resource.use.hdfs.location does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.saml2.sp.force.auth does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.stats.num.nulls.estimate.percent does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.parquet.timestamp.time.unit does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.rank.sketch does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.cm.encryptionzone.rootdir does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.use.googleregex.engine does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.ptf.rangecache.size does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.io.acid does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.bootstrap.dump.abort.write.txn.after.timeout does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.external.client.cloud.output.service.port does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.txn.filter.delete.events does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.zk.sm.session.timeout does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.scheduled.queries.executor.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.load.data.use.native.api does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.vectorized.ptf.max.memory.buffering.batch.count does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.task.scheduler.am.registry does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.bi.rewrite.countdistinct.sketch does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.druid.overlord.address.default does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.remove.sq_count_check does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.map.aggr.hash.min.reduction.lower.bound does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.basic.stats.max.threads.factor does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.webui.enable.cors does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.acid.renamepartition.makecopy does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.stats.retries.wait does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.constraints.join does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.vectorized.row.serde.inputformat.excludes does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.locks.max.partitions does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.query.reexecution.stats.cache.size does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.strict.checks.offset.no.orderby does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.txn.readonly.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.hook.proto.queue.capacity does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.view.tables.cache.enabled does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.scan.probedecode does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.security.authorization.tables.on.storagehandlers does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.show.operation.drilldown.link does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.txn.acid.metrics.reporting.interval does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.zookeeper.killquery.namespace does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.copy.file.list.iterator.retry does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.optimize.topnkey.efficiency.threshold does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.webui.explain.output does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.plugin.rpc.port does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.lock.query.string.max.length does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.llap.io.track.cache.usage does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.server2.authentication.jwt.jwks.skip.ssl.cert does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.retry.initial.delay does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.hook.proto.events.clean.freq does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.use.orc.codec.pool does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.query.results.cache.max.size does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.auto.convert.anti.join does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.strict.timestamp.conversion does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.repl.bootstrap.dump.open.txn.timeout does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.cardinality.preserving.join.optimization.factor does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.stats.max.num.stats does not exist
# 25/04/25 11:42:37 WARN HiveConf: HiveConf of name hive.mapjoin.full.outer does not exist
# 25/04/25 11:42:38 WARN ObjectStore: Failed to get database global_temp, returning NoSuchObjectException

# %% [markdown]
# # Test works table with SQL

# %%
spark.sql("SELECT * FROM works").show()
# Out:
# +--------------------+--------------------+--------------------+-----------+----------------+--------------------+-----------+--------+--------------------+---------------+--------------------+--------------------+--------+--------------------+-------------------+--------------------+--------------------+---------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------+--------------------+
# |   alternativeTitles|      availabilities|        contributors|createdDate|currentFrequency|         description|designation|duration|             edition|formerFrequency|              genres|            holdings|      id|         identifiers|             images|               items|           languages|lettering|               notes|              partOf|               parts| physicalDescription|          precededBy|          production|     referenceNumber|            subjects|         succeededBy|           thumbnail|               title|   type|            workType|
# +--------------------+--------------------+--------------------+-----------+----------------+--------------------+-----------+--------+--------------------+---------------+--------------------+--------------------+--------+--------------------+-------------------+--------------------+--------------------+---------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------+--------------------+
# |                  []|[{closed-stores, ...|[{{tsnyjm5v, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|                  []|hg7q3wz8|[{{sierra-system-...|[{r4hky3ka, Image}]|[{nq5etrue, [{{si...|[{ita, Italian, L...|     NULL|[{[In Italian.], ...|                  []|                  []|54 unnumbered lea...|                  []|[{[{G.A. Valvasso...|                NULL|                  []|                  []|                NULL|Physionomia / [Mi...|   Work|  {a, Books, Format}|
# |                  []|[{closed-stores, ...|                  []|       NULL|            NULL|Decorative and Ho...|         []|    NULL|                NULL|             []|                  []|                  []|xpk6b63t|[{{calm-record-id...|                 []|[{drxrd6n5, [{{si...|                  []|     NULL|                  []|[{ch2xsqkr, [{tmt...|                  []|              1 item|[{ku6n3jav, WA/HM...|[{[], [{18th July...|WA/HMM/CM/Sal/15/247|                  []|[{yhpg7n7p, WA/HM...|{[], {pdm, Public...|Sales catalogue: ...|   Work|{h, Archives and ...|
# |                  []|[{closed-stores, ...|                  []|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|                  []|sn3rvfcg|[{{calm-record-id...|                 []|[{xphs8d3j, [{{si...|                  []|     NULL|                  []|[{h8hpmfkd, [{cjv...|                  []|              1 file|[{dbbwj2te, GC/14...|[{[], [{1949, Per...|         GC/145/D.37|                  []|[{uzc32hvy, GC/14...|                NULL|'The civic restau...|   Work|{h, Archives and ...|
# |[Memoirs of the l...|[{online, Online,...|[{{ty9nz5n7, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|[{[Full text avai...|na3nt32r|[{{ebsco-alt-look...|                 []|                  []|                  []|     NULL|                  []|[{NULL, NULL, NUL...|                  []|                NULL|                  []|[{[], [], NULL, ,...|                NULL|                  []|                  []|                NULL|Memoirs of the li...|   Work|{v, E-books, Format}|
# |                  []|                  []|                  []|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|                  []|jukqck7m|[{{calm-record-id...|                 []|                  []|                  []|     NULL|                  []|[{dsvs3wkx, [{t3e...|[{cncz3hvg, PP/GF...|6 files, 1 oversi...|[{r5a7ceky, PP/GF...|[{[], [{1940-1975...|          PP/GFM/C.2|                  []|[{kfuwd6qg, PP/GF...|                NULL|  Honours and awards|Section|{h, Archives and ...|
# |[Second part of L...|[{online, Online,...|[{{hvma4h7m, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|[{[Full text avai...|fs2hg2wx|[{{ebsco-alt-look...|                 []|                  []|                  []|     NULL|                  []|[{NULL, NULL, NUL...|                  []|                NULL|                  []|[{[], [], NULL, ,...|                NULL|                  []|                  []|                NULL|Second part of La...|   Work|{v, E-books, Format}|
# |                  []|[{online, Online,...|[{{wjm2bve4, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|[{[{kqkakf66, [{{...|                  []|svxuqzm7|[{{sierra-system-...|                 []|[{NULL, [], [{[{{...|[{eng, English, L...|     NULL|[{[Report year: 1...|                  []|                  []|                NULL|                  []|[{[], [{[1945], P...|                NULL|[{[{qsazb8t4, [{{...|                  []|{[], {pdm, Public...|Annual report of ...|   Work|  {a, Books, Format}|
# |                  []|[{closed-stores, ...|[{{qen4a8vm, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|              2. ed.|             []|                  []|                  []|z5he9j2w|[{{sierra-system-...|                 []|[{ga84g56d, [{{si...|[{fre, French, La...|     NULL|                  []|                  []|                  []|8 unnumbered leav...|                  []|[{[{L. d'Houry, A...|                NULL|                  []|                  []|{[], {pdm, Public...|Traité des pertes...|   Work|  {a, Books, Format}|
# |                  []|[{closed-stores, ...|[{{yfvkdrf2, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|                  []|vcwcxgxy|[{{sierra-system-...|                 []|[{vbmr98x4, [{{si...|[{eng, English, L...|     NULL|[{[Text in Englis...|                  []|                  []|148 pages : illus...|                  []|[{[{International...|                NULL|[{[{yfvkdrf2, [{{...|                  []|                NULL|Manual of the Int...|   Work|  {a, Books, Format}|
# |                  []|[{closed-stores, ...|                  []|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|                  []|vbxhxbtg|[{{calm-record-id...|                 []|[{mfdyu23r, [{{si...|                  []|     NULL|                  []|[{z496etcr, [{bem...|                  []|              1 file|                  []|[{[], [{1921, Per...|       SA/FPA/SR18/1|                  []|[{cmk35c69, SA/FP...|                NULL|'Racial Solubles'...|   Work|{h, Archives and ...|
# |                  []|[{open-shelves, O...|[{{uh76e4pm, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|                  []|e67z6bdb|[{{sierra-system-...|                 []|[{aekmsq6d, [{{si...|[{eng, English, L...|     NULL|[{[Includes bibli...|                  []|                  []|xv, 253 pages 12 ...|                  []|[{[{The Commonwea...|                NULL|[{[{pt4vb2ez, [{{...|                  []|                NULL|Hypertension and ...|   Work|  {a, Books, Format}|
# |                  []|[{online, Online,...|[{{auq3b8u5, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|[{[{kqkakf66, [{{...|                  []|aqms559d|[{{sierra-system-...|                 []|[{NULL, [], [{[{{...|[{eng, English, L...|     NULL|[{[This work is a...|                  []|                  []|                NULL|                  []|[{[], [{1967, Per...|                NULL|[{[{d6jhgxuc, [{{...|                  []|{[], {cc-by, Attr...|[Report 1967] / M...|   Work|  {a, Books, Format}|
# |                  []|[{closed-stores, ...|[{{mdxxtgeg, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|2e éd. revue et a...|             []|                  []|                  []|a5eymvu5|[{{sierra-system-...|                 []|[{d76pav9m, [{{si...|[{eng, English, L...|     NULL|[{[Includes bibli...|                  []|                  []|x, 256 pages : il...|                  []|[{[{Octave Doin, ...|                NULL|[{[{d2ffsqqb, [{{...|                  []|                NULL|L'aérophagie : sy...|   Work|  {a, Books, Format}|
# |[Sacramental cate...|[{online, Online,...|                  []|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|[{[Full text avai...|wst65jth|[{{ebsco-alt-look...|                 []|                  []|                  []|     NULL|                  []|[{NULL, NULL, NUL...|                  []|                NULL|                  []|[{[], [], NULL, ,...|                NULL|                  []|                  []|                NULL|A sacramental cat...|   Work|{v, E-books, Format}|
# |[Observations on ...|[{online, Online,...|[{{a5vfsxn6, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|[{[Full text avai...|a58x8hgv|[{{ebsco-alt-look...|                 []|                  []|                  []|     NULL|                  []|[{NULL, NULL, NUL...|                  []|                NULL|                  []|[{[], [], NULL, ,...|                NULL|                  []|                  []|                NULL|Observations on a...|   Work|{v, E-books, Format}|
# |                  []|[{closed-stores, ...|                  []|       NULL|            NULL|Articles on commu...|         []|    NULL|                NULL|             []|                  []|                  []|r3ehc2zn|[{{calm-record-id...|                 []|[{fkue3pwf, [{{si...|                  []|     NULL|                  []|[{skf8xqe3, [{z9w...|                  []|              1 file|[{mm5hyt23, SA/ME...|[{[], [{1986-1987...|    SA/MED/H/2/5/1/4|                  []|                  []|                NULL|Articles and pape...|   Work|{h, Archives and ...|
# |[Christian journa...|[{online, Online,...|[{{ga2xh4cu, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|[{[Full text avai...|kqpu8n54|[{{ebsco-alt-look...|                 []|                  []|                  []|     NULL|                  []|[{NULL, NULL, NUL...|                  []|                NULL|                  []|[{[], [], NULL, ,...|                NULL|                  []|                  []|                NULL|The christian jou...|   Work|{v, E-books, Format}|
# |[Tentamen medicum...|[{online, Online,...|                  []|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|[{[Full text avai...|bunucrkz|[{{ebsco-alt-look...|                 []|                  []|                  []|     NULL|                  []|[{NULL, NULL, NUL...|                  []|                NULL|                  []|[{[], [], NULL, ,...|                NULL|                  []|                  []|                NULL|Tentamen medicum ...|   Work|{v, E-books, Format}|
# |                  []|[{closed-stores, ...|                  []|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|                  []|                  []|p8rs3ty3|[{{calm-record-id...|                 []|[{pm82gbux, [{{si...|                  []|     NULL|                  []|[{j3bcx5mw, [{efa...|                  []|              1 file|[{tef3ykcc, SA/AL...|[{[], [{Sep 1967,...|     SA/ALR/A.13/1/5|                  []|[{smy2bpxx, SA/AL...|                NULL|  Survey on Abortion|   Work|{h, Archives and ...|
# |                  []|[{online, Online,...|[{{my39339k, [{{l...|       NULL|            NULL|                NULL|         []|    NULL|                NULL|             []|[{[{kqkakf66, [{{...|                  []|nb4ws528|[{{sierra-system-...|                 []|[{NULL, [], [{[{{...|[{eng, English, L...|     NULL|[{[Contains publi...|                  []|                  []|                NULL|                  []|[{[], [{[1948], P...|                NULL|[{[{vw6m6da7, [{{...|                  []|{[], {cc-by-nc, A...|[Report of the Me...|   Work|  {a, Books, Format}|
# +--------------------+--------------------+--------------------+-----------+----------------+--------------------+-----------+--------+--------------------+---------------+--------------------+--------------------+--------+--------------------+-------------------+--------------------+--------------------+---------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------+--------------------+
# only showing top 20 rows

# %%
spark.sql("SELECT col.* FROM (SELECT EXPLODE(availabilities) FROM works)").show(5)
# Out:
# +-------------+-------------+------------+
# |           id|        label|        type|
# +-------------+-------------+------------+
# |closed-stores|Closed stores|Availability|
# |closed-stores|Closed stores|Availability|
# |       online|       Online|Availability|
# |closed-stores|Closed stores|Availability|
# |       online|       Online|Availability|
# +-------------+-------------+------------+
# only showing top 5 rows

# %%
spark.sql("SELECT col.* FROM (SELECT EXPLODE(production) FROM works)").show(5)
# Out:
# +--------------------+--------------------+--------+--------------------+-----------------+---------------+
# |              agents|               dates|function|               label|           places|           type|
# +--------------------+--------------------+--------+--------------------+-----------------+---------------+
# |[{G.A. Valvassore...|    [{1549, Period}]|    NULL|Venice : G.A. Val...|[{Venice, Place}]|ProductionEvent|
# |                  []|[{18th July 1923,...|    NULL|      18th July 1923|               []|ProductionEvent|
# |                  []|    [{1949, Period}]|    NULL|                1949|               []|ProductionEvent|
# |                  []|                  []|    NULL|                    |      [{, Place}]|ProductionEvent|
# |                  []|[{1940-1975, Peri...|    NULL|           1940-1975|               []|ProductionEvent|
# +--------------------+--------------------+--------+--------------------+-----------------+---------------+
# only showing top 5 rows

# %%
spark.sql("SELECT col.* FROM (SELECT EXPLODE(agents) FROM (SELECT col.* FROM (SELECT EXPLODE(production) FROM works)))").show(5)
# Out:
# +--------------------+-----+
# |               label| type|
# +--------------------+-----+
# |     G.A. Valvassore|Agent|
# |          L. d'Houry|Agent|
# |International Uni...|Agent|
# |The Commonwealth ...|Agent|
# |Oxford University...|Agent|
# +--------------------+-----+
# only showing top 5 rows

# %% [markdown]
# # Explode structs exploration

# %%
df_repartitioned.select("type").distinct().show()
# Out:
# +----------+
# |      type|
# +----------+
# |   Section|
# |      Work|
# |Collection|
# |    Series|
# +----------+

# %%
from pyspark.sql.functions import explode

# Explode the 'availabilities' array to create one row per element
exploded_df = df_repartitioned.select(
    explode("availabilities").alias("availability"))

# Select all fields from the availability struct and get distinct rows
unique_availabilities = exploded_df.select("availability.*").distinct()

unique_availabilities.show(truncate=False)
# Out:
# +-------------+-------------+------------+
# |id           |label        |type        |
# +-------------+-------------+------------+
# |closed-stores|Closed stores|Availability|
# |online       |Online       |Availability|
# |open-shelves |Open shelves |Availability|
# +-------------+-------------+------------+

# %%
# Explode the 'genres' array to get one row per genre struct
exploded_genres = df_repartitioned.select(explode("genres").alias("genre"))

# Select the 'label' field from the genre struct and get distinct values
unique_genre_labels = exploded_genres.select("genre.label").distinct()

# Show the unique genre labels
unique_genre_labels_pandas = unique_genre_labels.toPandas()
unique_genre_labels_pandas
# Out:
#                        label
# 0        Electronic journals
# 1                  Envelopes
# 2            Platinum prints
# 3     Dictionaries - English
# 4         Online-Publikation
# ...                      ...
# 1512              Caricature
# 1513          Pictorial Work
# 1514        Strips (teksten)
# 1515            Therapeutics
# 1516      Laboratory Manuals
#
# [1517 rows x 1 columns]

# %% [markdown]
# # Read Images dataset

# %%
df_img = spark.read.json(spark_path("../data/imports/images.json.gz"))

# %%
df_img.write.saveAsTable("images", mode="overwrite")

# %%
df_img.printSchema()
# Out:
# root
#  |-- aspectRatio: double (nullable = true)
#  |-- averageColor: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- locations: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- accessConditions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- method: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- status: struct (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |-- credit: string (nullable = true)
#  |    |    |-- license: struct (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- locationType: struct (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |-- source: struct (nullable = true)
#  |    |-- contributors: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- agent: struct (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- primary: boolean (nullable = true)
#  |    |    |    |-- roles: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |-- genres: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- concepts: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- languages: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |-- subjects: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- concepts: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |-- title: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- thumbnail: struct (nullable = true)
#  |    |-- accessConditions: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- method: struct (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- status: struct (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |-- credit: string (nullable = true)
#  |    |-- license: struct (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- locationType: struct (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- type: string (nullable = true)

# %%
df_img.show()
# Out:
# +-----------+------------+--------+--------------------+--------------------+--------------------+-----+
# |aspectRatio|averageColor|      id|           locations|              source|           thumbnail| type|
# +-----------+------------+--------+--------------------+--------------------+--------------------+-----+
# |  1.4705882|     #363935|msg3gj54|[{[{{view-online,...|{[], [], nf7cjmsg...|{[{{view-online, ...|Image|
# |      0.775|     #5f5b55|p4tj67k8|[{[{{view-online,...|{[], [{[{dhgr6mj5...|{[{{view-online, ...|Image|
# |       0.77|     #93908f|m5xrbr5f|[{[{{view-online,...|{[], [{[{esk9t6nc...|{[{{view-online, ...|Image|
# |      0.665|     #865f46|b864z9kp|[{[{{view-online,...|{[{{crk28fmh, Car...|{[{{view-online, ...|Image|
# |     0.8175|     #858585|ts7gybyc|[{[{{view-online,...|{[], [], tfm3zjpu...|{[{{view-online, ...|Image|
# |      0.665|     #757370|jkkhdjjz|[{[{{view-online,...|{[{{v4yhncct, Wil...|{[{{view-online, ...|Image|
# |     0.6325|     #b8b2ae|emf3xqh5|[{[{{view-online,...|{[{{yrj7ug2c, Luc...|{[{{view-online, ...|Image|
# |  1.6064258|     #979797|dmu6nms5|[{[{{view-online,...|{[{{n75925wv, Hea...|{[{{view-online, ...|Image|
# |      0.655|     #d0bea9|kn2qsydz|[{[{{view-online,...|{[], [], ncczkpq7...|{[{{view-online, ...|Image|
# |       0.89|     #c0c0c0|cqr7e8js|[{[{{view-online,...|{[], [{[{t5zepddp...|{[{{view-online, ...|Image|
# |  1.5037594|     #b9bcc1|hbt6pv8f|[{[{{view-online,...|{[{{yb4qd2nz, Car...|{[{{view-online, ...|Image|
# |      0.555|     #f2f2f2|qfq5xqf9|[{[{{view-online,...|{[{{vevq9pqy, Duj...|{[{{view-online, ...|Image|
# |  2.0408163|     #918f8f|r2mn39v5|[{[{{view-online,...|{[{{usqyr9ur, Tho...|{[{{view-online, ...|Image|
# |  1.3651878|     #6c6454|tgtrvte7|[{[{{view-online,...|{[], [{[{fmydsuw2...|{[{{view-online, ...|Image|
# |     1.5625|     #cbaa8d|jq3mr5bj|[{[{{view-online,...|{[], [], haqz47e3...|{[{{view-online, ...|Image|
# |     0.6575|     #8c8679|gjq2jamf|[{[{{view-online,...|{[{{zbcc8hrk, Mul...|{[{{view-online, ...|Image|
# |      0.645|     #bda690|qxe4bqg7|[{[{{view-online,...|{[], [{[{esk9t6nc...|{[{{view-online, ...|Image|
# |  1.3333334|     #68594b|qma54egm|[{[{{view-online,...|{[], [{[{heppxqaz...|{[{{view-online, ...|Image|
# |   1.532567|     #3c5441|drfzm5w6|[{[{{view-online,...|{[{{ekvnx3mw, Row...|{[{{view-online, ...|Image|
# |      0.645|     #bb9e83|vjy4mbb9|[{[{{view-online,...|{[{{xzj4jvwg, Gri...|{[{{view-online, ...|Image|
# +-----------+------------+--------+--------------------+--------------------+--------------------+-----+
# only showing top 20 rows

# %%
from pyspark.sql import functions as F

# %%
df_img.count()
# Out:
# 128755

# %%
spark.table("images").where(F.col("aspectRatio") == 1.0).count()
# Out:
# 480

# %%
import json

print(json.dumps(spark.table("images").first().asDict(), indent=4))
# Out:
# {
#     "aspectRatio": 1.4705882,
#     "averageColor": "#363935",
#     "id": "msg3gj54",
#     "locations": [
#         [
#             [
#                 [
#                     [
#                         "view-online",
#                         "View online",
#                         "AccessMethod"
#                     ],
#                     [
#                         "open",
#                         "Open",
#                         "AccessStatus"
#                     ],
#                     "AccessCondition"
#                 ]
#             ],
#             "Wellcome Collection",
#             [
#                 "cc-by",
#                 "Attribution 4.0 International (CC BY 4.0)",
#                 "License",
#                 "http://creativecommons.org/licenses/by/4.0/"
#             ],
#             [
#                 "iiif-image",
#                 "IIIF Image API",
#                 "LocationType"
#             ],
#             "DigitalLocation",
#             "https://iiif.wellcomecollection.org/image/N0014023/info.json"
#         ]
#     ],
#     "source": [
#         [],
#         [],
#         "nf7cjmsg",
#         [],
#         [],
#         "Hypertensive, vascular disease",
#         "Work"
#     ],
#     "thumbnail": [
#         [
#             [
#                 [
#                     "view-online",
#                     "View online",
#                     "AccessMethod"
#                 ],
#                 [
#                     "open",
#                     "Open",
#                     "AccessStatus"
#                 ],
#                 "AccessCondition"
#             ]
#         ],
#         "Wellcome Collection",
#         [
#             "cc-by",
#             "Attribution 4.0 International (CC BY 4.0)",
#             "License",
#             "http://creativecommons.org/licenses/by/4.0/"
#         ],
#         [
#             "iiif-image",
#             "IIIF Image API",
#             "LocationType"
#         ],
#         "DigitalLocation",
#         "https://iiif.wellcomecollection.org/image/N0014023/info.json"
#     ],
#     "type": "Image"
# }
