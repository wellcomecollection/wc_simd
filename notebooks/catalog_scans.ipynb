# %%
from wc_simd.utility import spark_path

# %%
from pyspark.sql import SparkSession


spark = SparkSession.builder \
    .appName("test_pyspark") \
    .config("spark.driver.memory", "12g") \
    .config("spark.executor.memory", "12g") \
    .config("spark.sql.orc.enableVectorizedReader", "false") \
    .config("spark.sql.parquet.columnarReaderBatchSize", "1024") \
    .config("spark.sql.orc.columnarReaderBatchSize", "1024") \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")
spark
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/06 10:33:07 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ip-172-31-22-145.eu-west-2.compute.internal:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>test_pyspark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType
import json
from pprint import pp

# %%
def print_json(id: str):
    row = spark.table("works").where(
        F.col("id") == id).first()
    row_dict = row.asDict(recursive=True)
    json_str = json.dumps(row_dict, indent=2)
    print(json_str)

# %% [markdown]
# # IIIF libraries
#
# - https://iiif-prezi.github.io/iiif-prezi3/
# - https://github.com/zimeon/iiif

# %% [markdown]
# # Collection Examples
#
# - Theme/Concept page: https://wellcomecollection.org/concepts/jabjbmgj

# %% [markdown]
# ## Work with many parts
# https://wellcomecollection.org/works/rqyum5sv

# %%
print_json("rqyum5sv")
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# {
#   "alternativeTitles": [],
#   "availabilities": [],
#   "contributors": [
#     {
#       "agent": {
#         "id": "wzggp2bj",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "label-derived",
#               "label": "Identifier derived from the label of the referent",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "twort, frederick william (1877-1950)"
#           }
#         ],
#         "label": "Twort, Frederick William (1877-1950)",
#         "type": "Agent"
#       },
#       "primary": true,
#       "roles": [],
#       "type": "Contributor"
#     }
#   ],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": "The material here consists largely of papers of Twort or about him, mainly his work at the Brown Institution. The bulk was arranged in files created by his son for the purpose of writing a biography. It includes: laboratory notes and correspondence, etc from the period 1903-1950,  including correspondence on the study of bacteriophages.",
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [],
#   "holdings": [],
#   "id": "rqyum5sv",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "calm-record-id",
#         "label": "Calm RecordIdentifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "e51fede1-e4ea-4ea4-89fc-e7301e24ad40"
#     },
#     {
#       "identifierType": {
#         "id": "calm-ref-no",
#         "label": "Calm RefNo",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "GC176"
#     },
#     {
#       "identifierType": {
#         "id": "calm-altref-no",
#         "label": "Calm AltRefNo",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "GC/176"
#     },
#     {
#       "identifierType": {
#         "id": "wellcome-accession-number",
#         "label": "Accession number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "854"
#     },
#     {
#       "identifierType": {
#         "id": "wellcome-accession-number",
#         "label": "Accession number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "1157"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b19689469"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "1968946"
#     }
#   ],
#   "images": [],
#   "items": [],
#   "languages": [],
#   "lettering": null,
#   "notes": [
#     {
#       "contents": [
#         "Twort went into research shortly after he qualified in medicine in 1900. In 1909 he was appointed Superintendent of the Brown Institution in South London, a post he held until the building was destroyed during the Blitz in 1944, apart from a period of service in Salonika at the Base Laboratories during World War I. In 1929 he was elected FRS and in 1931 the title of Professor of Bacteriology was conferred on him by the University of London. He did important work on the bacteriophage and was involved in controversy with F\u00e9lix d'H\u00e9relle over priority in research findings. Twort's research interests were wide and included developing improved wireless reception and work on removing impurities in latex. Described in an obituary as an 'erratic genius' he was no stranger to controversy, criticising his military superiors during his war service and initiating a legal case against the Medical Research Council when they terminated their funding to the Brown Institution.\nDetails of a biography of Twort by his son are given below."
#       ],
#       "noteType": {
#         "id": "biographical-note",
#         "label": "Biographical note",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "These papers were received in Oct 1993 from Dr Antony Twort, the son of FW Twort, and an additional accession in May 2003 from the same"
#       ],
#       "noteType": {
#         "id": "acquisition-note",
#         "label": "Acquisition note",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "At Wellcome Collection: PP/COL, PP/CRA, PP/GSW, PP/HAR, PP/VAN, SA/AMC, SA/HIS, SA/LIS, GC/4, 12, 33, 70, 130, 170, 177, 180, 200, 221, 278, RAMC, WA/BSR, WA/PHO."
#       ],
#       "noteType": {
#         "id": "related-material",
#         "label": "Related material",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "Most of the material was in post files, from which items have been removed and placed in acid free folders but otherwise kept together. Some slight rearrangement of the experimental notes in B.3 was undertaken to restore the sequence. The material relating to his wireless research, B.2, was loose in a file. One file of loose material labelled 'Various papers and letters', which includes career items, testimonials, congratulatory letters, and general correspondence with colleagues, associates and friends, has been sorted into several files now listed in Section A.\nThe sections are as follows:\nA\tPersonalia\nB\tResearch\nC\tCase against the Medical Research Council"
#       ],
#       "noteType": {
#         "id": "arrangement-note",
#         "label": "Arrangement",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     }
#   ],
#   "partOf": [],
#   "parts": [
#     {
#       "id": "hnmjdjrk",
#       "referenceNumber": "GC/176/A",
#       "title": "Personalia",
#       "totalDescendentParts": 9,
#       "totalParts": 7,
#       "type": "Section"
#     },
#     {
#       "id": "q86p94m9",
#       "referenceNumber": "GC/176/B",
#       "title": "Research",
#       "totalDescendentParts": 22,
#       "totalParts": 7,
#       "type": "Section"
#     },
#     {
#       "id": "dkhx5djp",
#       "referenceNumber": "GC/176/C",
#       "title": "Case against the Medical Research Council",
#       "totalDescendentParts": 7,
#       "totalParts": 2,
#       "type": "Section"
#     }
#   ],
#   "physicalDescription": "3 boxes",
#   "precededBy": [],
#   "production": [
#     {
#       "agents": [],
#       "dates": [
#         {
#           "label": "1896-1983",
#           "type": "Period"
#         }
#       ],
#       "function": null,
#       "label": "1896-1983",
#       "places": [],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": "GC/176",
#   "subjects": [
#     {
#       "concepts": [
#         {
#           "id": "tnjzjnct",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "bacteriology"
#             }
#           ],
#           "label": "Bacteriology",
#           "type": "Concept"
#         }
#       ],
#       "id": "tnjzjnct",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "label-derived",
#             "label": "Identifier derived from the label of the referent",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "bacteriology"
#         }
#       ],
#       "label": "Bacteriology",
#       "type": "Subject"
#     }
#   ],
#   "succeededBy": [],
#   "thumbnail": null,
#   "title": "Twort, Frederick William",
#   "type": "Collection",
#   "workType": {
#     "id": "h",
#     "label": "Archives and manuscripts",
#     "type": "Format"
#   }
# }

# %% [markdown]
# ## Work (Archives and manuscripts) (locationType.id: `iiif-presentation`)
# https://wellcomecollection.org/works/gumbfr2w

# %%
print_json("gumbfr2w")
# Out:
# [Stage 17:==============>                                           (1 + 3) / 4]
# {
#   "alternativeTitles": [],
#   "availabilities": [
#     {
#       "id": "closed-stores",
#       "label": "Closed stores",
#       "type": "Availability"
#     },
#     {
#       "id": "online",
#       "label": "Online",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": "Correspondence, diagrams, press-cuttings, patent applications.",
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [],
#   "holdings": [],
#   "id": "gumbfr2w",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "calm-record-id",
#         "label": "Calm RecordIdentifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "94ee05ca-b065-40f5-9e5e-78085048f0cb"
#     },
#     {
#       "identifierType": {
#         "id": "calm-ref-no",
#         "label": "Calm RefNo",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "GC176/B/2"
#     },
#     {
#       "identifierType": {
#         "id": "calm-altref-no",
#         "label": "Calm AltRefNo",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "GC/176/B/2"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b19131525"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "1913152"
#     },
#     {
#       "identifierType": {
#         "id": "wellcome-digcode",
#         "label": "Wellcome digcode",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "digadhoc"
#     },
#     {
#       "identifierType": {
#         "id": "mets",
#         "label": "METS",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b19131525"
#     }
#   ],
#   "images": [],
#   "items": [
#     {
#       "id": "cfsu233k",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "sierra-system-number",
#             "label": "Sierra system number",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "i17787580"
#         },
#         {
#           "identifierType": {
#             "id": "sierra-identifier",
#             "label": "Sierra identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "1778758"
#         }
#       ],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "online-request",
#                 "label": "Online request",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "open",
#                 "label": "Open",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": "Closed stores",
#           "license": null,
#           "linkText": null,
#           "locationType": {
#             "id": "closed-stores",
#             "label": "Closed stores",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "PhysicalLocation",
#           "url": null
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     },
#     {
#       "id": null,
#       "identifiers": [],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "view-online",
#                 "label": "View online",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "open-with-advisory",
#                 "label": "Open with advisory",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": null,
#           "license": {
#             "id": "inc",
#             "label": "In copyright",
#             "type": "License",
#             "url": "http://rightsstatements.org/vocab/InC/1.0/"
#           },
#           "linkText": null,
#           "locationType": {
#             "id": "iiif-presentation",
#             "label": "IIIF Presentation API",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "DigitalLocation",
#           "url": "https://iiif.wellcomecollection.org/presentation/v2/b19131525"
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     }
#   ],
#   "languages": [],
#   "lettering": null,
#   "notes": [],
#   "partOf": [
#     {
#       "id": "q86p94m9",
#       "partOf": [
#         {
#           "id": "rqyum5sv",
#           "partOf": null,
#           "referenceNumber": "GC/176",
#           "title": "Twort, Frederick William",
#           "totalDescendentParts": 41,
#           "totalParts": 3,
#           "type": "Collection"
#         }
#       ],
#       "referenceNumber": "GC/176/B",
#       "title": "Research",
#       "totalDescendentParts": 22,
#       "totalParts": 7,
#       "type": "Section"
#     }
#   ],
#   "parts": [],
#   "physicalDescription": "1 file",
#   "precededBy": [
#     {
#       "id": "x7t6cgnn",
#       "referenceNumber": "GC/176/B/1",
#       "title": "Bacteriophage",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     }
#   ],
#   "production": [
#     {
#       "agents": [],
#       "dates": [
#         {
#           "label": "1927-1933",
#           "type": "Period"
#         }
#       ],
#       "function": null,
#       "label": "1927-1933",
#       "places": [],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": "GC/176/B/2",
#   "subjects": [],
#   "succeededBy": [
#     {
#       "id": "mdbcb8ck",
#       "referenceNumber": "GC/176/B/3",
#       "title": "Laboratory notes",
#       "totalDescendentParts": 6,
#       "totalParts": 6,
#       "type": "Series"
#     },
#     {
#       "id": "cj4gxk8c",
#       "referenceNumber": "GC/176/B/4",
#       "title": "Shepherd's Industries: Rubber Research and 'DX'",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "akghfat3",
#       "referenceNumber": "GC/176/B/5",
#       "title": "Laboratory notebooks",
#       "totalDescendentParts": 9,
#       "totalParts": 9,
#       "type": "Series"
#     },
#     {
#       "id": "kdrdd85j",
#       "referenceNumber": "GC/176/B/6",
#       "title": "Loose notes 'The Essential Substance'",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     },
#     {
#       "id": "qfrzvnza",
#       "referenceNumber": "GC/176/B/7",
#       "title": "Ledger: 'The Brown Institution Special Research Account'",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Work"
#     }
#   ],
#   "thumbnail": null,
#   "title": "Short-wave wireless coils",
#   "type": "Work",
#   "workType": {
#     "id": "h",
#     "label": "Archives and manuscripts",
#     "type": "Format"
#   }
# }
# 25/04/22 15:06:14 WARN HikariPool: HikariPool-1 - Thread starvation or clock leap detected (housekeeper delta=14m57s49ms).
# 25/04/22 15:06:14 WARN HikariPool: HikariPool-2 - Thread starvation or clock leap detected (housekeeper delta=14m57s48ms).

# %% [markdown]
# ## Work (Digital Images) with one image (locationType.id: `iiif-image`)
# - https://wellcomecollection.org/works/nf7cjmsg
# - Image: https://iiif.wellcomecollection.org/image/N0014023/full/600,/0/default.jpg (Change "600" for different width)

# %%
print_json("nf7cjmsg")
# Out:
# [Stage 19:==============>                                           (1 + 3) / 4]
# {
#   "alternativeTitles": [],
#   "availabilities": [
#     {
#       "id": "online",
#       "label": "Online",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": "Scan - axial, brain",
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [],
#   "holdings": [],
#   "id": "nf7cjmsg",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "miro-image-number",
#         "label": "Miro image number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "N0014023"
#     },
#     {
#       "identifierType": {
#         "id": "miro-library-reference",
#         "label": "Miro library reference",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "NMSB Frame No NOVIDEO"
#     }
#   ],
#   "images": [
#     {
#       "id": "msg3gj54",
#       "type": "Image"
#     }
#   ],
#   "items": [
#     {
#       "id": null,
#       "identifiers": [],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "view-online",
#                 "label": "View online",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "open",
#                 "label": "Open",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": "Wellcome Collection",
#           "label": null,
#           "license": {
#             "id": "cc-by",
#             "label": "Attribution 4.0 International (CC BY 4.0)",
#             "type": "License",
#             "url": "http://creativecommons.org/licenses/by/4.0/"
#           },
#           "linkText": null,
#           "locationType": {
#             "id": "iiif-image",
#             "label": "IIIF Image API",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "DigitalLocation",
#           "url": "https://iiif.wellcomecollection.org/image/N0014023/info.json"
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     }
#   ],
#   "languages": [],
#   "lettering": null,
#   "notes": [],
#   "partOf": [],
#   "parts": [],
#   "physicalDescription": null,
#   "precededBy": [],
#   "production": [],
#   "referenceNumber": null,
#   "subjects": [],
#   "succeededBy": [],
#   "thumbnail": {
#     "accessConditions": [],
#     "license": {
#       "id": "cc-by",
#       "label": "Attribution 4.0 International (CC BY 4.0)",
#       "type": "License",
#       "url": "http://creativecommons.org/licenses/by/4.0/"
#     },
#     "locationType": {
#       "id": "thumbnail-image",
#       "label": "Thumbnail image",
#       "type": "LocationType"
#     },
#     "type": "DigitalLocation",
#     "url": "https://iiif.wellcomecollection.org/image/N0014023/full/300,/0/default.jpg"
#   },
#   "title": "Hypertensive, vascular disease",
#   "type": "Work",
#   "workType": {
#     "id": "q",
#     "label": "Digital Images",
#     "type": "Format"
#   }
# }

# %% [markdown]
# ## Work (Book) (No digital) (locationType.id: `open-shelves`)
# - https://wellcomecollection.org/works/m6uy6knc

# %%
print_json("m6uy6knc")
# Out:
# [Stage 6:==============>                                            (1 + 3) / 4]
# {
#   "alternativeTitles": [],
#   "availabilities": [
#     {
#       "id": "open-shelves",
#       "label": "Open shelves",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [
#     {
#       "agent": {
#         "id": "rcncxsjb",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "lc-names",
#               "label": "Library of Congress Name authority records",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "n80117079"
#           }
#         ],
#         "label": "Simoons, Frederick J.",
#         "type": "Person"
#       },
#       "primary": true,
#       "roles": [],
#       "type": "Contributor"
#     }
#   ],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": null,
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [],
#   "holdings": [],
#   "id": "m6uy6knc",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b10274911"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "1027491"
#     },
#     {
#       "identifierType": {
#         "id": "isbn",
#         "label": "International Standard Book Number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "0299159000"
#     },
#     {
#       "identifierType": {
#         "id": "isbn",
#         "label": "International Standard Book Number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "0299159043"
#     }
#   ],
#   "images": [],
#   "items": [
#     {
#       "id": "vfsrwfby",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "sierra-system-number",
#             "label": "Sierra system number",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "i10320039"
#         },
#         {
#           "identifierType": {
#             "id": "sierra-identifier",
#             "label": "Sierra identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "1032003"
#         }
#       ],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "open-shelves",
#                 "label": "Open shelves",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": null,
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": "History of Medicine",
#           "license": null,
#           "linkText": null,
#           "locationType": {
#             "id": "open-shelves",
#             "label": "Open shelves",
#             "type": "LocationType"
#           },
#           "shelfmark": "AQ.U",
#           "type": "PhysicalLocation",
#           "url": null
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     }
#   ],
#   "languages": [
#     {
#       "id": "eng",
#       "label": "English",
#       "type": "Language"
#     }
#   ],
#   "lettering": null,
#   "notes": [
#     {
#       "contents": [
#         "Includes bibliographic references and index"
#       ],
#       "noteType": {
#         "id": "bibliographic-info",
#         "label": "Bibliographic information",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "Copy 1 Supplier/Donor: CMB"
#       ],
#       "noteType": {
#         "id": "general-note",
#         "label": "Notes",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     }
#   ],
#   "partOf": [],
#   "parts": [],
#   "physicalDescription": "xv, 568 pages : illustrations, map ; 24 cm",
#   "precededBy": [],
#   "production": [
#     {
#       "agents": [
#         {
#           "label": "University of Wisconsin Press",
#           "type": "Agent"
#         }
#       ],
#       "dates": [
#         {
#           "label": "[1998], \u00a91998",
#           "type": "Period"
#         }
#       ],
#       "function": null,
#       "label": "Madison : University of Wisconsin Press, [1998], \u00a91998.",
#       "places": [
#         {
#           "label": "Madison",
#           "type": "Place"
#         }
#       ],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": null,
#   "subjects": [
#     {
#       "concepts": [
#         {
#           "id": "usqt7qt8",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "plants"
#             }
#           ],
#           "label": "Plants",
#           "type": "Concept"
#         },
#         {
#           "id": "m7x7qxg6",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "history"
#             }
#           ],
#           "label": "history",
#           "type": "Concept"
#         }
#       ],
#       "id": "esgbhpdu",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D010944"
#         }
#       ],
#       "label": "Plants - history",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "c8w3e37q",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D008273"
#             }
#           ],
#           "label": "Magic",
#           "type": "Concept"
#         }
#       ],
#       "id": "c8w3e37q",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D008273"
#         }
#       ],
#       "label": "Magic",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "jszzsnpj",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D005495"
#             }
#           ],
#           "label": "Folklore",
#           "type": "Concept"
#         }
#       ],
#       "id": "jszzsnpj",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D005495"
#         }
#       ],
#       "label": "Folklore",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "akpq4prm",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D011035"
#             }
#           ],
#           "label": "Podophyllum",
#           "type": "Concept"
#         }
#       ],
#       "id": "akpq4prm",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D011035"
#         }
#       ],
#       "label": "Podophyllum",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "bj8j5d6t",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D018649"
#             }
#           ],
#           "label": "Ocimum basilicum",
#           "type": "Concept"
#         }
#       ],
#       "id": "bj8j5d6t",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D018649"
#         }
#       ],
#       "label": "Ocimum basilicum",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "jabjbmgj",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D005737"
#             }
#           ],
#           "label": "Garlic",
#           "type": "Concept"
#         }
#       ],
#       "id": "jabjbmgj",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D005737"
#         }
#       ],
#       "label": "Garlic",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "phrahkz4",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D005894"
#             }
#           ],
#           "label": "Panax",
#           "type": "Concept"
#         }
#       ],
#       "id": "phrahkz4",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D005894"
#         }
#       ],
#       "label": "Panax",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "yjdwjxk2",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D007887"
#             }
#           ],
#           "label": "Fabaceae",
#           "type": "Concept"
#         }
#       ],
#       "id": "yjdwjxk2",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D007887"
#         }
#       ],
#       "label": "Fabaceae",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "c3vm7m37",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "plants, medicinal"
#             }
#           ],
#           "label": "Plants, Medicinal",
#           "type": "Concept"
#         },
#         {
#           "id": "m7x7qxg6",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "history"
#             }
#           ],
#           "label": "history",
#           "type": "Concept"
#         }
#       ],
#       "id": "j3kse2wd",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D010946"
#         }
#       ],
#       "label": "Plants, Medicinal - history",
#       "type": "Subject"
#     }
#   ],
#   "succeededBy": [],
#   "thumbnail": null,
#   "title": "Plants of life, plants of death / Frederick J. Simoons.",
#   "type": "Work",
#   "workType": {
#     "id": "a",
#     "label": "Books",
#     "type": "Format"
#   }
# }

# %% [markdown]
# ## Work (Book) (locationType.id: `online-resource`) (go.gale.com)
# - https://wellcomecollection.org/works/mtbrsqa8
# - https://go.gale.com/ps/i.do?p=ECCO&u=wellcome&id=GALE%7CCW0123958160&v=2.1&it=r

# %%
print_json("mtbrsqa8")
# Out:
# {
#   "alternativeTitles": [
#     "Case of His Majesties sugar plantations (Online)"
#   ],
#   "availabilities": [
#     {
#       "id": "online",
#       "label": "Online",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": null,
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [],
#   "holdings": [
#     {
#       "enumeration": [
#         "Full text available: 1670."
#       ],
#       "location": {
#         "accessConditions": [
#           {
#             "method": {
#               "id": "view-online",
#               "label": "View online",
#               "type": "AccessMethod"
#             },
#             "status": {
#               "id": "licensed-resources",
#               "label": "Licensed resources",
#               "type": "AccessStatus"
#             },
#             "type": "AccessCondition"
#           }
#         ],
#         "label": null,
#         "linkText": "Available in Eighteenth Century Collections Online.",
#         "locationType": {
#           "id": "online-resource",
#           "label": "Online resource",
#           "type": "LocationType"
#         },
#         "shelfmark": null,
#         "type": "DigitalLocation",
#         "url": "https://resolver.ebscohost.com/Redirect/PRL?EPPackageLocationID=4205.1530096.0&epcustomerid=s7451719"
#       },
#       "note": null,
#       "type": "Holdings"
#     }
#   ],
#   "id": "mtbrsqa8",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "ebsco-alt-lookup",
#         "label": "EBSCO lookup identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "ebs1530096e"
#     }
#   ],
#   "images": [],
#   "items": [],
#   "languages": [],
#   "lettering": null,
#   "notes": [],
#   "partOf": [
#     {
#       "id": null,
#       "partOf": null,
#       "referenceNumber": null,
#       "title": "Eighteenth Century Collections Online",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Series"
#     }
#   ],
#   "parts": [],
#   "physicalDescription": null,
#   "precededBy": [],
#   "production": [
#     {
#       "agents": [
#         {
#           "label": "ProQuest UMI Dissertation Publishing",
#           "type": "Agent"
#         }
#       ],
#       "dates": [
#         {
#           "label": "[1670]",
#           "type": "Period"
#         }
#       ],
#       "function": null,
#       "label": "ProQuest UMI Dissertation Publishing [1670]",
#       "places": [],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": null,
#   "subjects": [],
#   "succeededBy": [],
#   "thumbnail": null,
#   "title": "The case of His Majesties sugar plantations",
#   "type": "Work",
#   "workType": {
#     "id": "v",
#     "label": "E-books",
#     "type": "Format"
#   }
# }

# %% [markdown]
# ## Work (Book) (locationType.id: `online-resource`) (www.proquest.com/eebo)
# - https://wellcomecollection.org/works/u7xtg8mj

# %%
print_json("u7xtg8mj")
# Out:
# [Stage 12:======================================>                  (8 + 4) / 12]
# {
#   "alternativeTitles": [],
#   "availabilities": [
#     {
#       "id": "online",
#       "label": "Online",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [
#     {
#       "agent": {
#         "id": "ckk9ffrq",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "lc-names",
#               "label": "Library of Congress Name authority records",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "n84177453"
#           }
#         ],
#         "label": "Coley, Henry, 1633-1704?",
#         "type": "Person"
#       },
#       "primary": true,
#       "roles": [],
#       "type": "Contributor"
#     }
#   ],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": null,
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [
#     {
#       "concepts": [
#         {
#           "id": "kqkakf66",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "electronic books"
#             }
#           ],
#           "label": "Electronic books",
#           "type": "Genre"
#         }
#       ],
#       "label": "Electronic books",
#       "type": "Genre"
#     }
#   ],
#   "holdings": [],
#   "id": "u7xtg8mj",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b17595770"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "1759577"
#     }
#   ],
#   "images": [],
#   "items": [
#     {
#       "id": null,
#       "identifiers": [],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "view-online",
#                 "label": "View online",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "licensed-resources",
#                 "label": "Licensed resources",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": null,
#           "license": null,
#           "linkText": "View online",
#           "locationType": {
#             "id": "online-resource",
#             "label": "Online resource",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "DigitalLocation",
#           "url": "https://www.proquest.com/eebo/docview/2240852944/shibboleth?accountid=14952"
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     }
#   ],
#   "languages": [
#     {
#       "id": "eng",
#       "label": "English",
#       "type": "Language"
#     }
#   ],
#   "lettering": null,
#   "notes": [
#     {
#       "contents": [
#         "Reproduction of original in the Bodleian Library."
#       ],
#       "noteType": {
#         "id": "general-note",
#         "label": "Notes",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "Wing A1454"
#       ],
#       "noteType": {
#         "id": "references-note",
#         "label": "References note",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "Electronic reproduction. Ann Arbor, Mich. : UMI, 1999- (Early English books online) Digital version of: (Early English books, 1641-1700 ; 1056:8) s1999    miun s"
#       ],
#       "noteType": {
#         "id": "reproduction-note",
#         "label": "Reproduction note",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     }
#   ],
#   "partOf": [
#     {
#       "id": null,
#       "partOf": null,
#       "referenceNumber": null,
#       "title": "Early English books online",
#       "totalDescendentParts": 0,
#       "totalParts": 0,
#       "type": "Series"
#     }
#   ],
#   "parts": [],
#   "physicalDescription": "48 unnumbered pages",
#   "precededBy": [],
#   "production": [
#     {
#       "agents": [
#         {
#           "label": "Printed by S.S. for the Company of Stationers",
#           "type": "Agent"
#         }
#       ],
#       "dates": [
#         {
#           "label": "1677",
#           "type": "Period"
#         }
#       ],
#       "function": null,
#       "label": "London : Printed by S.S. for the Company of Stationers, 1677.",
#       "places": [
#         {
#           "label": "London",
#           "type": "Place"
#         }
#       ],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": null,
#   "subjects": [
#     {
#       "concepts": [
#         {
#           "id": "dtqj5skq",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "lc-subjects",
#                 "label": "Library of Congress Subject Headings (LCSH)",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "sh86005784"
#             }
#           ],
#           "label": "Almanacs, English",
#           "type": "Concept"
#         }
#       ],
#       "id": "dtqj5skq",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "lc-subjects",
#             "label": "Library of Congress Subject Headings (LCSH)",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "sh86005784"
#         }
#       ],
#       "label": "Almanacs, English",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "rz2b24za",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "lc-subjects",
#                 "label": "Library of Congress Subject Headings (LCSH)",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "sh85044264"
#             }
#           ],
#           "label": "Ephemerides",
#           "type": "Concept"
#         }
#       ],
#       "id": "rz2b24za",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "lc-subjects",
#             "label": "Library of Congress Subject Headings (LCSH)",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "sh85044264"
#         }
#       ],
#       "label": "Ephemerides",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "bejypfcz",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "astrology"
#             }
#           ],
#           "label": "Astrology",
#           "type": "Concept"
#         },
#         {
#           "id": "pqf4m9zw",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "early works to 1800"
#             }
#           ],
#           "label": "Early works to 1800",
#           "type": "Concept"
#         }
#       ],
#       "id": "fd22k2kf",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "lc-subjects",
#             "label": "Library of Congress Subject Headings (LCSH)",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "sh2007100969"
#         }
#       ],
#       "label": "Astrology - Early works to 1800",
#       "type": "Subject"
#     }
#   ],
#   "succeededBy": [],
#   "thumbnail": null,
#   "title": "Nuncius coelestis, or, Urania's messenger : being a brief description and survey of the year of humane redemption 1677 : unto which is numbered ... : accomodated to the meridian of London ... / by Henry Coley.",
#   "type": "Work",
#   "workType": {
#     "id": "a",
#     "label": "Books",
#     "type": "Format"
#   }
# }

# %% [markdown]
# ## Work (Book) (locationType.id: `iiif-presentation`) (embedded PDF)
# - https://wellcomecollection.org/works/deybwyaf

# %%
print_json("deybwyaf")
# Out:
# {
#   "alternativeTitles": [
#     "Galen commentary on Hippocrates Epidemics book 1 parts I-III"
#   ],
#   "availabilities": [
#     {
#       "id": "online",
#       "label": "Online",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [
#     {
#       "agent": {
#         "id": "ch4dx5r2",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "lc-names",
#               "label": "Library of Congress Name authority records",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "n79059644"
#           }
#         ],
#         "label": "Galen",
#         "type": "Person"
#       },
#       "primary": true,
#       "roles": [
#         {
#           "label": "author",
#           "type": "ContributionRole"
#         }
#       ],
#       "type": "Contributor"
#     },
#     {
#       "agent": {
#         "id": "mx4zvzk6",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "lc-names",
#               "label": "Library of Congress Name authority records",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "no2006133710"
#           }
#         ],
#         "label": "Vagelpohl, Uwe",
#         "type": "Person"
#       },
#       "primary": false,
#       "roles": [
#         {
#           "label": "translator,",
#           "type": "ContributionRole"
#         },
#         {
#           "label": "writer of added commentary",
#           "type": "ContributionRole"
#         }
#       ],
#       "type": "Contributor"
#     },
#     {
#       "agent": {
#         "id": "ae94d67v",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "lc-names",
#               "label": "Library of Congress Name authority records",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "n80145641"
#           }
#         ],
#         "label": "\u1e24unayn ibn Is\u1e25\u0101q al-\u02bbIb\u0101d\u012b, 809?-873",
#         "type": "Person"
#       },
#       "primary": false,
#       "roles": [
#         {
#           "label": "translator",
#           "type": "ContributionRole"
#         }
#       ],
#       "type": "Contributor"
#     }
#   ],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": "<p>The present volume offers the first critical edition of Book 1 of the medieval Arabic translation of Galen's Commentary on the Hippocratic Epidemics, produced by the celebrated translator Hunayn ibn Ish\u0101q (d. ca. 870). The edition is based on all extant Arabic textual witnesses, including the Arabic secondary transmission.The translation of Galen's commentary became a crucial source for the development of medicine in the Islamic world, especially in the nascent field of clinical medicine. It was frequently read and quoted in later Arabic medical literature, and several Arabic authors used it to produce a wide range of didactic writings for medical students and practising physicians.The English translation, which aims to convey some of the flavour of the Arabic translation, comes with extensive notes on the differences between the Greek original and the Arabic translation. A thorough comparison between the two versions of the commentary provides important insights into the translation style and technique of Hunayn ibn Ish\u0101q and his circle and Arabic medical terminology at the time.</p>",
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [
#     {
#       "concepts": [
#         {
#           "id": "kqkakf66",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "electronic books"
#             }
#           ],
#           "label": "Electronic books",
#           "type": "Genre"
#         }
#       ],
#       "label": "Electronic books",
#       "type": "Genre"
#     }
#   ],
#   "holdings": [],
#   "id": "deybwyaf",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b28820757"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "2882075"
#     },
#     {
#       "identifierType": {
#         "id": "isbn",
#         "label": "International Standard Book Number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "9783110406597"
#     },
#     {
#       "identifierType": {
#         "id": "isbn",
#         "label": "International Standard Book Number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "3110406594"
#     }
#   ],
#   "images": [],
#   "items": [
#     {
#       "id": null,
#       "identifiers": [],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "view-online",
#                 "label": "View online",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "open",
#                 "label": "Open",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": null,
#           "license": {
#             "id": "cc-by-nc-nd",
#             "label": "Attribution-NonCommercial-NoDerivatives 4.0 International (CC BY-NC-ND 4.0)",
#             "type": "License",
#             "url": "https://creativecommons.org/licenses/by-nc-nd/4.0/"
#           },
#           "linkText": null,
#           "locationType": {
#             "id": "iiif-presentation",
#             "label": "IIIF Presentation API",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "DigitalLocation",
#           "url": "https://iiif.wellcomecollection.org/presentation/v2/b28820757"
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     }
#   ],
#   "languages": [],
#   "lettering": null,
#   "notes": [
#     {
#       "contents": [
#         "Includes bibliographical references and index."
#       ],
#       "noteType": {
#         "id": "bibliographic-info",
#         "label": "Bibliographic information",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "Text in English and Arabic."
#       ],
#       "noteType": {
#         "id": "language-note",
#         "label": "Language note",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     },
#     {
#       "contents": [
#         "Description based on online resource; title from PDF title page (OAPEN, viewed July 8, 2016)."
#       ],
#       "noteType": {
#         "id": "general-note",
#         "label": "Notes",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     }
#   ],
#   "partOf": [],
#   "parts": [],
#   "physicalDescription": "1 online resource (736 pages)",
#   "precededBy": [],
#   "production": [
#     {
#       "agents": [
#         {
#           "label": "De Gruyter Akademie Forschung",
#           "type": "Agent"
#         }
#       ],
#       "dates": [
#         {
#           "label": "2014",
#           "type": "Period"
#         }
#       ],
#       "function": {
#         "label": "Publication",
#         "type": "Concept"
#       },
#       "label": "Berlin : De Gruyter Akademie Forschung, 2014.",
#       "places": [
#         {
#           "label": "Berlin",
#           "type": "Place"
#         }
#       ],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": null,
#   "subjects": [
#     {
#       "concepts": [
#         {
#           "id": "r6wmagke",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "medicine (general)"
#             }
#           ],
#           "label": "Medicine (General)",
#           "type": "Concept"
#         }
#       ],
#       "id": "r6wmagke",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "label-derived",
#             "label": "Identifier derived from the label of the referent",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "medicine (general)"
#         }
#       ],
#       "label": "Medicine (General)",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "b5sh23kc",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "epidemics"
#             }
#           ],
#           "label": "Epidemics",
#           "type": "Concept"
#         },
#         {
#           "id": "m7x7qxg6",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "history"
#             }
#           ],
#           "label": "history",
#           "type": "Concept"
#         }
#       ],
#       "id": "ksacfrt9",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D058872Q000266"
#         }
#       ],
#       "label": "Epidemics - history",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "maegwwt7",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "greek world"
#             }
#           ],
#           "label": "Greek World",
#           "type": "Concept"
#         },
#         {
#           "id": "m7x7qxg6",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "label-derived",
#                 "label": "Identifier derived from the label of the referent",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "history"
#             }
#           ],
#           "label": "history",
#           "type": "Concept"
#         }
#       ],
#       "id": "vuhhhrp2",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D018645Q000266"
#         }
#       ],
#       "label": "Greek World - history",
#       "type": "Subject"
#     },
#     {
#       "concepts": [
#         {
#           "id": "hka26xg3",
#           "identifiers": [
#             {
#               "identifierType": {
#                 "id": "nlm-mesh",
#                 "label": "Medical Subject Headings (MeSH) identifier",
#                 "type": "IdentifierType"
#               },
#               "type": "Identifier",
#               "value": "D049690"
#             }
#           ],
#           "label": "History, Ancient",
#           "type": "Concept"
#         }
#       ],
#       "id": "hka26xg3",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "nlm-mesh",
#             "label": "Medical Subject Headings (MeSH) identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "D049690"
#         }
#       ],
#       "label": "History, Ancient",
#       "type": "Subject"
#     }
#   ],
#   "succeededBy": [],
#   "thumbnail": {
#     "accessConditions": [],
#     "license": {
#       "id": "cc-by-nc-nd",
#       "label": "Attribution-NonCommercial-NoDerivatives 4.0 International (CC BY-NC-ND 4.0)",
#       "type": "License",
#       "url": "https://creativecommons.org/licenses/by-nc-nd/4.0/"
#     },
#     "locationType": {
#       "id": "thumbnail-image",
#       "label": "Thumbnail image",
#       "type": "LocationType"
#     },
#     "type": "DigitalLocation",
#     "url": "https://iiif.wellcomecollection.org/thumb/b28820757"
#   },
#   "title": "Galeni In Hippocratis Epidemiarum librum I commentariorum I-III : versionem Arabicam / edidit, in lingnam Anglican vertit, commentatus est Uwe Vagelpohl = Galen commentary on Hippocrates Epidemics book 1 parts I-III : edition of the Arabic version / with English translation and notes by Uwe Vagelpohl.",
#   "type": "Work",
#   "workType": {
#     "id": "a",
#     "label": "Books",
#     "type": "Format"
#   }
# }

# %% [markdown]
# # Works with IIIF presentation

# %% [markdown]
# ## Rows with item location url has "presentation"

# %%
import pyspark.sql.functions as F

items_filter = """
  exists(
    items, i ->
        exists(i.locations, l ->
            l.url LIKE '%/presentation/%')
  )
"""

df_works_w_presentation = spark.table("works").filter(
    F.expr(items_filter)
)

# %%
df_works_w_presentation.count()
# Out:
# 339129

# %% [markdown]
# ## Create flattened df

# %%
import json

print(json.dumps(df_works_w_presentation.first().asDict(recursive=True), indent=2))
# Out:
# {
#   "alternativeTitles": [],
#   "availabilities": [
#     {
#       "id": "closed-stores",
#       "label": "Closed stores",
#       "type": "Availability"
#     }
#   ],
#   "contributors": [
#     {
#       "agent": {
#         "id": "tsnyjm5v",
#         "identifiers": [
#           {
#             "identifierType": {
#               "id": "lc-names",
#               "label": "Library of Congress Name authority records",
#               "type": "IdentifierType"
#             },
#             "type": "Identifier",
#             "value": "n83318295"
#           }
#         ],
#         "label": "Scot, Michael, approximately 1175-approximately 1234",
#         "type": "Person"
#       },
#       "primary": true,
#       "roles": [],
#       "type": "Contributor"
#     }
#   ],
#   "createdDate": null,
#   "currentFrequency": null,
#   "description": null,
#   "designation": [],
#   "duration": null,
#   "edition": null,
#   "formerFrequency": [],
#   "genres": [],
#   "holdings": [],
#   "id": "hg7q3wz8",
#   "identifiers": [
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b24736223"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "2473622"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-system-number",
#         "label": "Sierra system number",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "b13255149"
#     },
#     {
#       "identifierType": {
#         "id": "sierra-identifier",
#         "label": "Sierra identifier",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "1325514"
#     },
#     {
#       "identifierType": {
#         "id": "wellcome-digcode",
#         "label": "Wellcome digcode",
#         "type": "IdentifierType"
#       },
#       "type": "Identifier",
#       "value": "digproquest"
#     }
#   ],
#   "images": [
#     {
#       "id": "r4hky3ka",
#       "type": "Image"
#     }
#   ],
#   "items": [
#     {
#       "id": "nq5etrue",
#       "identifiers": [
#         {
#           "identifierType": {
#             "id": "sierra-system-number",
#             "label": "Sierra system number",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "i18740765"
#         },
#         {
#           "identifierType": {
#             "id": "sierra-identifier",
#             "label": "Sierra identifier",
#             "type": "IdentifierType"
#           },
#           "type": "Identifier",
#           "value": "1874076"
#         }
#       ],
#       "locations": [
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "online-request",
#                 "label": "Online request",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "open",
#                 "label": "Open",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": "Closed stores",
#           "license": null,
#           "linkText": null,
#           "locationType": {
#             "id": "closed-stores",
#             "label": "Closed stores",
#             "type": "LocationType"
#           },
#           "shelfmark": "EPB/A/5887",
#           "type": "PhysicalLocation",
#           "url": null
#         },
#         {
#           "accessConditions": [
#             {
#               "method": {
#                 "id": "view-online",
#                 "label": "View online",
#                 "type": "AccessMethod"
#               },
#               "note": null,
#               "status": {
#                 "id": "restricted",
#                 "label": "Restricted",
#                 "type": "AccessStatus"
#               },
#               "terms": null,
#               "type": "AccessCondition"
#             }
#           ],
#           "credit": null,
#           "label": null,
#           "license": {
#             "id": "pdm",
#             "label": "Public Domain Mark",
#             "type": "License",
#             "url": "https://creativecommons.org/share-your-work/public-domain/pdm/"
#           },
#           "linkText": null,
#           "locationType": {
#             "id": "iiif-presentation",
#             "label": "IIIF Presentation API",
#             "type": "LocationType"
#           },
#           "shelfmark": null,
#           "type": "DigitalLocation",
#           "url": "https://iiif.wellcomecollection.org/presentation/v2/b13255149"
#         }
#       ],
#       "note": null,
#       "title": null,
#       "type": "Item"
#     }
#   ],
#   "languages": [
#     {
#       "id": "ita",
#       "label": "Italian",
#       "type": "Language"
#     }
#   ],
#   "lettering": null,
#   "notes": [
#     {
#       "contents": [
#         "In Italian."
#       ],
#       "noteType": {
#         "id": "general-note",
#         "label": "Notes",
#         "type": "NoteType"
#       },
#       "type": "Note"
#     }
#   ],
#   "partOf": [],
#   "parts": [],
#   "physicalDescription": "54 unnumbered leaves : title page with woodcut border ; (8vo)",
#   "precededBy": [],
#   "production": [
#     {
#       "agents": [
#         {
#           "label": "G.A. Valvassore",
#           "type": "Agent"
#         }
#       ],
#       "dates": [
#         {
#           "label": "1549",
#           "type": "Period"
#         }
#       ],
#       "function": null,
#       "label": "Venice : G.A. Valvassore, 1549.",
#       "places": [
#         {
#           "label": "Venice",
#           "type": "Place"
#         }
#       ],
#       "type": "ProductionEvent"
#     }
#   ],
#   "referenceNumber": null,
#   "subjects": [],
#   "succeededBy": [],
#   "thumbnail": null,
#   "title": "Physionomia / [Michael Scot].",
#   "type": "Work",
#   "workType": {
#     "id": "a",
#     "label": "Books",
#     "type": "Format"
#   }
# }

# %%
df_works_item_urls = (
    spark.table("works")
      # 1) explode each item so we have work‐level id + item struct
      .select(
          F.col("id"),
          F.explode(F.col("items")).alias("item")
      )
      # 2) from each item, explode only the locations whose URL matches
      .select(
          F.col("id"),
          F.col("item.id").alias("item_id"),
          F.explode(
              F.expr("filter(item.locations, l -> l.url LIKE '%/presentation/%')")
          ).alias("location")
      )
      # 3) pick out just the fields you want
      .select(
          F.col("id"),
          F.col("item_id"),
          F.col("location.url").alias("url")
      )
)

# %%
df_works_item_urls.count()
# Out:
# 339927

# %%
df_works_item_urls.show(truncate=False)
# Out:
# +--------+--------+-------------------------------------------------------------+
# |id      |item_id |url                                                          |
# +--------+--------+-------------------------------------------------------------+
# |hg7q3wz8|nq5etrue|https://iiif.wellcomecollection.org/presentation/v2/b13255149|
# |xpk6b63t|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b31669098|
# |svxuqzm7|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b31482363|
# |z5he9j2w|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b3300433x|
# |aqms559d|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b30134201|
# |a5eymvu5|d76pav9m|https://iiif.wellcomecollection.org/presentation/v2/b32852125|
# |p8rs3ty3|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b18733189|
# |nb4ws528|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b19788071|
# |j76my5qt|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b2105048x|
# |ykcjtz2m|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b32852642|
# |ztzxzwuu|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b29130232|
# |p7cdkwc5|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b3007017x|
# |g8arrmmz|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b2494208x|
# |xpzgtwyy|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b30603171|
# |deka442a|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b29999005|
# |msbakad4|svfekhz6|https://iiif.wellcomecollection.org/presentation/v2/b20418243|
# |js76k9ke|np7dshud|https://iiif.wellcomecollection.org/presentation/v2/b15702790|
# |fvr9vpge|yr8pmhmj|https://iiif.wellcomecollection.org/presentation/v2/b28665016|
# |pz9r3m6q|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b31847535|
# |a7pf6bu3|NULL    |https://iiif.wellcomecollection.org/presentation/v2/b21146445|
# +--------+--------+-------------------------------------------------------------+
# only showing top 20 rows

# %%
# Unique URLs
df_works_item_urls.select("url").distinct().count()
# Out:
# 338984

# %%
# df_works_item_urls.groupBy(["id", "item_id"]).agg(
#     F.collect_list("url").alias("urls")
# ).show(truncate=False)


# Find maximum number of URLs per item order by descending
df_works_item_urls.groupBy(["id", "item_id"]).agg(
    F.size(F.collect_list("url")).alias("num_urls")
).groupBy("id", "item_id").agg(
    F.max("num_urls").alias("max_num_urls")
).orderBy(F.desc("max_num_urls")).show(truncate=False)
# Out:
# [Stage 35:=========>                                              (3 + 14) / 17]
# +--------+-------+------------+
# |id      |item_id|max_num_urls|
# +--------+-------+------------+
# |qkyfeq4d|NULL   |19          |
# |sc3xpn3j|NULL   |18          |
# |vez58dmn|NULL   |11          |
# |ggyv4adm|NULL   |10          |
# |r4rwzsbt|NULL   |8           |
# |q2patb5a|NULL   |7           |
# |nj5b25th|NULL   |6           |
# |j8h7vmzr|NULL   |6           |
# |rm3d64jc|NULL   |6           |
# |mfxhfvsx|NULL   |6           |
# |uhjrxtzz|NULL   |6           |
# |zh5wjfjy|NULL   |6           |
# |gn63jhnz|NULL   |5           |
# |e99p98sd|NULL   |5           |
# |v6zpdnkg|NULL   |5           |
# |gbz8s3pk|NULL   |5           |
# |zs4p5mjk|NULL   |5           |
# |sdg85vcr|NULL   |5           |
# |bqtxkyv7|NULL   |5           |
# |f8pgtxv9|NULL   |5           |
# +--------+-------+------------+
# only showing top 20 rows

# %%
df_works_item_urls_subset = df_works_item_urls.sample(
    withReplacement=False,
    fraction=0.01,
    seed=42
)
df_works_item_urls_subset.count()
# Out:
# 3398

# %% [markdown]
# ## Fetch IIIF Manifests

# %%
import requests
from pyspark.sql import functions as F
from pyspark.sql.types import StringType

# 1) UDF to fetch JSON text


def fetch_json(url: str) -> str:
    try:
        resp = requests.get(url, timeout=10)
        resp.raise_for_status()
        return resp.text
    except Exception:
        return None


fetch_json_udf = F.udf(fetch_json, StringType())

# -------------------------------------------------------
# Assume you already have `item_urls` from the previous step:
#   columns: work_id, item_id, url
# -------------------------------------------------------

# 2) Attach raw JSON string
with_json_str = (
    df_works_item_urls_subset
    .withColumn("json_str", fetch_json_udf(F.col("url")))
)

# 3) Infer schema once (optional; run this just one time)
raw_json_rdd = (
    with_json_str
    .select("json_str")
    .rdd
    .map(lambda r: r.json_str)
    .filter(lambda txt: txt is not None)
)
inferred_schema = spark.read.json(raw_json_rdd).schema

# 4) Parse into a Struct column, drop the raw text
result_df = (
    with_json_str
    .withColumn("json_data", F.from_json(F.col("json_str"), inferred_schema))
    .drop("json_str")
)

result_df.printSchema()
result_df.show(truncate=False)

# %%
result_df.schema
# Out:
# StructType([StructField('id', StringType(), True), StructField('item_id', StringType(), True), StructField('url', StringType(), True), StructField('json_data', StructType([StructField('@context', StringType(), True), StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('label', StringType(), True), StructField('license', StringType(), True), StructField('logo', StringType(), True), StructField('metadata', ArrayType(StructType([StructField('label', StringType(), True), StructField('value', StringType(), True)]), True), True), StructField('otherContent', ArrayType(StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('label', StringType(), True)]), True), True), StructField('related', StructType([StructField('@id', StringType(), True), StructField('format', StringType(), True), StructField('label', StringType(), True)]), True), StructField('seeAlso', StructType([StructField('@id', StringType(), True), StructField('format', StringType(), True), StructField('label', StringType(), True), StructField('profile', StringType(), True)]), True), StructField('sequences', ArrayType(StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('canvases', ArrayType(StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('height', LongType(), True), StructField('images', ArrayType(StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('motivation', StringType(), True), StructField('on', StringType(), True), StructField('resource', StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('format', StringType(), True), StructField('height', LongType(), True), StructField('service', StringType(), True), StructField('width', LongType(), True)]), True)]), True), True), StructField('label', StringType(), True), StructField('otherContent', ArrayType(StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('label', StringType(), True)]), True), True), StructField('seeAlso', StructType([StructField('@id', StringType(), True), StructField('format', StringType(), True), StructField('label', StringType(), True), StructField('profile', StringType(), True)]), True), StructField('thumbnail', StructType([StructField('@id', StringType(), True), StructField('@type', StringType(), True), StructField('service', StructType([StructField('@context', StringType(), True), StructField('@id', StringType(), True), StructField('height', LongType(), True), StructField('profile', StringType(), True), StructField('protocol', StringType(), True), StructField('sizes', ArrayType(StructType([StructField('height', LongType(), True), StructField('width', LongType(), True)]), True), True), StructField('width', LongType(), True)]), True)]), True), StructField('width', LongType(), True), StructField('within', StringType(), True)]), True), True), StructField('label', StringType(), True), StructField('rendering', StringType(), True), StructField('viewingHint', StringType(), True)]), True), True), StructField('service', ArrayType(StructType([StructField('@context', StringType(), True), StructField('@id', StringType(), True), StructField('accessHint', StringType(), True), StructField('authService', StructType([StructField('@context', StringType(), True), StructField('@id', StringType(), True), StructField('confirmLabel', StringType(), True), StructField('description', StringType(), True), StructField('failureDescription', StringType(), True), StructField('failureHeader', StringType(), True), StructField('header', StringType(), True), StructField('label', StringType(), True), StructField('profile', StringType(), True), StructField('service', ArrayType(StructType([StructField('@context', StringType(), True), StructField('@id', StringType(), True), StructFiel ...

# %%
pages_df = result_df.withColumn(
    "pages",
    # grab the first element of the sequences array, then count its canvases
    F.expr("size(json_data.sequences[0].canvases)")
).select("id", "item_id", "url", "pages")

# %% [markdown]
# ## Estimate number of scanned pages with a 1% sample

# %%
pages_df.agg(F.sum("pages")).show()
# Out:
# [Stage 74:====================================================>   (16 + 1) / 17]
# +----------+
# |sum(pages)|
# +----------+
# |    427656|
# +----------+

# %%
427656 / 0.01
# Out:
# 42765600.0

# %% [markdown]
# ## Estimate number of scanned pages with a 0.1% sample

# %%
pages_df.agg(F.sum("pages")).show()
# Out:
# [Stage 66:====================================================>   (16 + 1) / 17]
# +----------+
# |sum(pages)|
# +----------+
# |     36511|
# +----------+

# %%
36511/0.001
# Out:
# 36511000.0
